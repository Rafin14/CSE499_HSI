# %%
import numpy as np
import nltk
#nltk.download('punkt_tab')
from transformers import AutoModelForCausalLM, AutoTokenizer
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from sentence_transformers import SentenceTransformer

# %%
# List of labels.   #everything must be in lower case.   # underscore needed for more than one word as input label

#labels = ["hypolimnas_misippus", "danaus_chrysippus", "amauris_ochlea", "acraea_egina"]
labels = ["heartwood", "sapwood"]

# %% [markdown]
# # Generate Contextual Paragraphs Using an LLM

# %%
# Load the Qwen2.5-1.5B-Instruct model and tokenizer        #most download
model_name = "Qwen/Qwen2.5-1.5B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_name, trust_remote_code=True).half().cuda()

# %%
# Function to generate text for a label
def generate_paragraph(label):
    
    prompt = f"Write a factual and descriptive paragraph about {label}, focus on thier characteristics, description, differences and uses"
    
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    outputs = model.generate(**inputs, max_new_tokens=250, temperature=0.7)
    
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Generate paragraphs for each label
contextual_paragraphs_Qwen1_5B = {label: generate_paragraph(label) for label in labels}

# Print the generated paragraphs
for label, paragraph in contextual_paragraphs_Qwen1_5B.items():
    
    print(f"{label}: {paragraph}\n")
# Out:
# heartwood: Write a factual and descriptive paragraph about heartwood, focus on thier characteristics, description and anatomy. 250-300 words
#
# Heartwood is the thick central core of a tree that contains no living cells. Unlike sapwood, which is made up of dead but active wood cells, heartwood is composed entirely of dead cells. This makes it more resistant to decay and pests than sapwood.
#
# The heartwood in trees develops over time as they grow larger. As the innermost parts of the trunk or branches age and die, they are replaced by new growth from the cambium layer. The result is a strong, durable wood with beautiful grain patterns that vary widely depending on species.
#
# Heartwood can be identified visually because its color is usually darker and often banded or mottled compared to surrounding sapwood. It may also have knots or irregularities due to past damage or stress during the tree's life cycle. In woodworking, artisans carefully select pieces of heartwood for their strength and aesthetic qualities.
#
# Overall, heartwood plays an important role in both nature and human culture through its durability and unique appearance. Its rich history spans millennia, making it a treasured material in many fields including architecture, furniture-making, and musical instruments.
#
# This text has been written in a clear and informative style while providing accurate information about heartwood.
#
# sapwood: Write a factual and descriptive paragraph about sapwood, focus on thier characteristics, description and anatomy. 5-6 sentences.
#
# Sapwood is the outermost layer of wood that contains living cells and conducts water from the roots to the rest of the tree. It is lighter in color than heartwood due to its higher content of lignin, which makes it more resistant to rot and decay. Sapwood also has a thin boundary with heartwood, separating them by a distinct line. This distinction between the two types of wood can be important for woodworking projects as it affects the strength and durability of the finished product. Additionally, sapwood often has a smoother texture compared to heartwood, making it ideal for veneer or decorative applications. Overall, understanding the properties and characteristics of sapwood is crucial for anyone involved in woodworking or forestry operations.

# %% [markdown]
# #  Prepare Corpus for Word Embedding

# %% [markdown]
# Combine the generated paragraphs into a single corpus

# %%
corpus = "\n".join(contextual_paragraphs_Qwen1_5B.values())

print(corpus)
# Out:
# Write a factual and descriptive paragraph about heartwood, focus on thier characteristics, description and anatomy. 250-300 words
#
# Heartwood is the thick central core of a tree that contains no living cells. Unlike sapwood, which is made up of dead but active wood cells, heartwood is composed entirely of dead cells. This makes it more resistant to decay and pests than sapwood.
#
# The heartwood in trees develops over time as they grow larger. As the innermost parts of the trunk or branches age and die, they are replaced by new growth from the cambium layer. The result is a strong, durable wood with beautiful grain patterns that vary widely depending on species.
#
# Heartwood can be identified visually because its color is usually darker and often banded or mottled compared to surrounding sapwood. It may also have knots or irregularities due to past damage or stress during the tree's life cycle. In woodworking, artisans carefully select pieces of heartwood for their strength and aesthetic qualities.
#
# Overall, heartwood plays an important role in both nature and human culture through its durability and unique appearance. Its rich history spans millennia, making it a treasured material in many fields including architecture, furniture-making, and musical instruments.
#
# This text has been written in a clear and informative style while providing accurate information about heartwood.
# Write a factual and descriptive paragraph about sapwood, focus on thier characteristics, description and anatomy. 5-6 sentences.
#
# Sapwood is the outermost layer of wood that contains living cells and conducts water from the roots to the rest of the tree. It is lighter in color than heartwood due to its higher content of lignin, which makes it more resistant to rot and decay. Sapwood also has a thin boundary with heartwood, separating them by a distinct line. This distinction between the two types of wood can be important for woodworking projects as it affects the strength and durability of the finished product. Additionally, sapwood often has a smoother texture compared to heartwood, making it ideal for veneer or decorative applications. Overall, understanding the properties and characteristics of sapwood is crucial for anyone involved in woodworking or forestry operations.

# %% [markdown]
# # Generate Word Embeddings

# %% [markdown]
# Word2Vec Embeddings

# %%
# Tokenize the corpus into sentences
sentences = [word_tokenize(paragraph.lower()) for paragraph in contextual_paragraphs_Qwen1_5B.values()]

# Train Word2Vec model
word2vec_model = Word2Vec(sentences, vector_size=300, window=5, min_count=1, workers=4)

# Retrieve embeddings for each label
label_embeddings = {label: word2vec_model.wv[label] for label in labels}

print(label_embeddings)
# Out:
# {'heartwood': array([-2.3906983e-03,  1.4879876e-03,  7.1068550e-04,  2.5278607e-03,
#        -1.6401529e-03, -1.6169355e-03, -1.9412265e-03,  1.2758502e-03,
#        -1.4936653e-03,  2.7830193e-03, -1.3968637e-03, -3.0820339e-03,
#        -1.6715266e-03,  2.0953901e-03, -2.1831659e-03, -1.7706989e-03,
#        -2.3743915e-03,  2.0804645e-03,  1.1151930e-03,  9.5779955e-04,
#        -1.0721458e-03,  2.0030313e-03, -2.0210496e-03, -6.5585307e-04,
#        -1.9203986e-03, -3.3742501e-04, -7.6623954e-04,  2.8584402e-03,
#         1.7482278e-05, -2.9280968e-03, -1.7468358e-03, -2.3055056e-03,
#         9.4320334e-04,  3.1781583e-03, -2.0049938e-03,  2.7731869e-03,
#         2.9197580e-03, -2.4057268e-03, -2.9476017e-03,  3.1929407e-03,
#         2.7370697e-03, -1.5731459e-03, -2.2511003e-03,  2.5530702e-03,
#         1.3298662e-03,  2.7736013e-03, -2.4622390e-03, -3.1398213e-03,
#         5.1787525e-04, -3.2352987e-03, -1.6192313e-03, -1.1772988e-03,
#         3.1772223e-03,  2.8669876e-03, -9.4482274e-04,  2.0368043e-03,
#         2.7822573e-03, -7.1216066e-04,  3.1740486e-03,  2.4125406e-03,
#         6.5904768e-04, -1.3396109e-03, -1.7242723e-03, -1.0034814e-03,
#         2.5989749e-03, -2.0173837e-03, -9.8127348e-04,  3.0240559e-03,
#        -2.3502749e-04, -6.3067542e-05,  3.7333200e-05,  2.9138981e-03,
#        -8.8142499e-04, -1.9391228e-03,  2.4621156e-03, -2.4487551e-03,
#        -3.0369218e-03, -6.5992918e-04, -2.8346162e-03,  7.5854012e-05,
#         6.2449719e-04, -8.3765201e-04, -2.1865696e-03, -1.9650550e-04,
#        -3.2760913e-04,  1.1193590e-03,  2.7469574e-03,  1.8430100e-03,
#         2.7934476e-03, -3.2054067e-03,  3.0259639e-03, -8.6143339e-04,
#         2.9627432e-03,  7.6830189e-04,  1.1493062e-03, -3.2664810e-03,
#        -3.1971342e-03,  2.8851859e-03, -9.9522830e-04,  8.7036774e-04,
#         2.0827109e-03, -1.3087888e-05,  3.2849261e-03, -3.1601984e-04,
#        -3.2687129e-03, -2.2727735e-03, -3.6404646e-04, -2.8627883e-03,
#         2.4215318e-03,  1.1689218e-03, -2.9171135e-03,  2.6857380e-03,
#         3.0380273e-03,  1.9350576e-03,  2.2328326e-03, -3.2126401e-03,
#         2.2782794e-04, -3.1766850e-03, -1.2617114e-03,  1.0655156e-04,
#        -6.1957275e-05,  5.5169314e-04,  1.1138719e-03,  7.7715586e-04,
#         1.8154585e-03,  2.4892392e-03, -2.0920772e-03,  2.5568279e-03,
#         2.1431905e-03,  3.2812508e-03,  1.4219991e-03, -1.1919456e-03,
#        -1.2102324e-03, -2.1286016e-04, -5.2689540e-04,  3.1412707e-03,
#         2.9878767e-04,  1.3392648e-03,  1.2181614e-03, -2.8596299e-03,
#         2.1540129e-03,  2.7596545e-03, -6.1327673e-04,  7.6524960e-04,
#        -2.1407879e-03, -2.0433720e-03,  2.7695345e-03, -9.9973695e-04,
#         2.3013386e-03,  5.0171529e-04, -7.6592539e-04,  1.0350992e-03,
#        -1.3515872e-03, -6.1448256e-04,  4.4336673e-04,  1.6787100e-03,
#        -4.3414038e-04,  1.7701194e-04, -2.8040828e-03,  3.2119437e-03,
#        -2.8851398e-03,  2.4740095e-03,  1.3155767e-03, -2.2385258e-03,
#        -1.7159871e-03, -2.6731093e-03, -1.6663030e-03,  2.4978567e-03,
#         3.2112589e-03,  6.8072812e-04,  2.5346843e-04,  3.1710928e-03],
#       dtype=float32)}

# %%
# Get the vocabulary list
vocabulary_list = list(word2vec_model.wv.key_to_index.keys())

# Print the vocabulary list
print(vocabulary_list)
# Out:
# ['.', ',', 'and', 'the', 'of', 'heartwood', 'a', 'sapwood', 'is', 'to', 'it', 'in', 'or', 'for', 'wood', 'its', 'cells', 'characteristics', 'woodworking', 'has', 'on', 'this', 'about', 'as', 'tree', 'that', 'than', 'they', 'making', 'decay', 'durability', 'write', 'by', 'important', 'from', 'overall', 'resistant', 'strength', 'with', 'can', 'due', 'be', 'also', 'compared', 'color', 'layer', 'often', 'more', 'focus', 'anatomy', 'description', 'dead', 'which', 'living', 'thier', 'makes', 'paragraph', 'descriptive', 'factual', 'contains', 'result', 'thick', 'strong', 'durable', 'words', 'beautiful', '250-300', 'widely', 'grain', 'patterns', 'vary', 'core', 'depending', 'species', 'identified', 'visually', 'because', 'usually', 'central', 'no', 'cambium', 'growth', 'entirely', 'pests', 'composed', 'active', 'darker', 'develops', 'over', 'time', 'but', 'grow', 'up', 'larger', 'innermost', 'parts', 'trunk', 'made', 'branches', 'age', 'die', 'are', 'replaced', 'unlike', 'new', 'trees', 'operations', 'banded', 'roots', 'separating', 'boundary', 'thin', 'rot', 'lignin', 'content', 'higher', 'lighter', 'rest', 'water', 'clear', 'conducts', 'outermost', 'sentences', '5-6', 'information', 'accurate', 'providing', 'while', 'style', 'them', 'distinct', 'line', 'distinction', 'involved', 'anyone', 'crucial', 'properties', 'understanding', 'applications', 'decorative', 'veneer', 'ideal', 'texture', 'smoother', 'additionally', 'product', 'finished', 'affects', 'projects', 'types', 'two', 'between', 'informative', 'written', 'mottled', 'life', 'plays', 'qualities', 'aesthetic', 'their', 'pieces', 'select', 'carefully', 'artisans', 'cycle', "'s", 'been', 'during', 'stress', 'damage', 'past', 'irregularities', 'knots', 'have', 'forestry', 'surrounding', 'an', 'role', 'both', 'nature', 'text', 'instruments', 'musical', 'furniture-making', 'architecture', 'including', 'fields', 'many', 'material', 'treasured', 'millennia', 'spans', 'history', 'rich', 'appearance', 'unique', 'through', 'culture', 'human', 'may']

# %% [markdown]
# BERT Embeddings

# %%
# Load a pre-trained BERT model
bert_model = SentenceTransformer('all-MiniLM-L6-v2')

# Generate embeddings for each label's paragraph
label_embeddings_b = {label: bert_model.encode(paragraph) for label, paragraph in contextual_paragraphs_Qwen1_5B.items()}

print(label_embeddings_b)
# Out:
# {'heartwood': array([ 4.77939956e-02, -3.07247657e-02,  1.08484374e-02, -5.37702115e-04,
#         7.12271333e-02, -1.95555110e-02, -1.82913672e-02, -2.57748812e-02,
#         7.48094842e-02,  6.53318837e-02, -4.71443981e-02,  1.98347699e-02,
#        -3.66703384e-02,  1.30697386e-03, -1.00413729e-02, -2.11795755e-02,
#         1.64323058e-02, -3.54270674e-02, -4.55403030e-02,  3.29334587e-02,
#         5.86275086e-02,  6.15587756e-02, -5.75726554e-02, -3.61469854e-03,
#         2.81673372e-02, -4.30600047e-02, -8.33306760e-02, -1.27847819e-02,
#         5.31014241e-03,  1.38385193e-02,  1.09778389e-01,  1.91196874e-02,
#         6.22714907e-02,  7.61768222e-02, -8.57131407e-02,  6.80446327e-02,
#         3.15507012e-03, -6.39113635e-02,  3.06881405e-02,  3.92321981e-02,
#        -6.77363500e-02,  2.43599452e-02, -2.16351170e-02, -1.05603347e-02,
#         4.03676229e-03,  1.19033894e-02, -1.18596349e-02, -5.47433943e-02,
#        -4.55513299e-02, -1.57920141e-02, -6.02350980e-02, -7.51601160e-02,
#        -5.10276332e-02, -4.57268544e-02, -2.09758878e-02,  3.44997235e-02,
#        -8.39437172e-03, -5.20008840e-02, -5.39384084e-04, -2.92405989e-02,
#         5.56914881e-02,  9.16511342e-02,  4.03251871e-02, -3.46000008e-02,
#        -2.29355190e-02, -1.22047169e-02, -7.30788987e-03,  1.94302779e-02,
#         3.73482406e-02,  3.59559222e-03,  3.95065099e-02,  3.41734141e-02,
#         1.16037689e-01, -9.91385281e-02, -5.28472522e-03,  6.71848804e-02,
#         8.75751227e-02,  1.30114686e-02,  7.95680955e-02, -7.05841482e-02,
#        -6.66877925e-02, -2.98662353e-02, -5.77249117e-02, -3.78566459e-02,
#        -3.40433009e-02,  6.57062307e-02,  2.61564013e-02,  9.79714189e-03,
#         4.27939231e-03, -6.03429042e-02,  3.17217298e-02, -1.73250735e-02,
#        -6.64496794e-02,  1.41657423e-02,  2.87270620e-02, -2.21638512e-02,
#        -3.86276729e-02,  2.53043119e-02,  2.73409151e-02,  2.34721098e-02,
#         1.19607651e-03, -6.51486740e-02, -5.29670948e-03, -4.11294289e-02,
#        -1.59279653e-03, -8.87134969e-02, -4.33548689e-02,  7.94332381e-03,
#        -2.71157622e-02,  5.20144850e-02,  2.94232052e-02, -3.81464139e-02,
#         2.65335087e-02, -4.51313779e-02, -2.69910563e-02,  2.29411889e-02,
#         2.19422597e-02,  3.40992212e-02, -1.56172216e-02, -2.83106435e-02,
#         3.85548957e-02,  6.43820688e-02, -2.74934731e-02, -5.32974838e-04,
#         3.73184606e-02, -1.09224379e-01, -2.04354003e-02, -2.29600407e-02,
#        -6.48677498e-02,  2.50546192e-03, -2.71497574e-02, -4.49777282e-08,
#        -6.60228208e-02,  2.10330244e-02,  4.03996781e-02, -6.99738935e-02,
#        -9.54998061e-02, -2.58367732e-02,  9.21381861e-02,  7.64185563e-02,
#        -5.79362288e-02,  4.84170429e-02, -6.77218835e-04,  4.94614989e-02,
#        -9.75342020e-02,  1.13640018e-02,  3.52982357e-02, -1.51262358e-02,
#        -3.67254727e-02, -5.37876487e-02,  2.32533496e-02, -4.21121456e-02,
#         6.95327073e-02, -1.06939852e-01, -4.04491127e-02,  1.00028299e-01,
#         2.73873527e-02, -8.52580965e-02, -3.95206213e-02,  1.49337370e-02,
#        -2.48880703e-02,  4.00818065e-02,  7.76979104e-02,  1.00996152e-01,
#         3.25132906e-02,  7.66647607e-02,  1.67988278e-02,  6.14756159e-02,
#         6.06392324e-03, -3.21308523e-02, -8.13461617e-02,  5.66800721e-02,
#         2.75296834e-03, -1.31782040e-01, -2.88140140e-02, -2.36699916e-02,
#         1.86562426e-02, -6.35892227e-02,  5.59491776e-02,  2.56382655e-02,
#        -2.80883685e-02,  4.52203490e-02, -2.25445461e-02, -6.99045360e-02,
#         1.67577318e-03,  3.95416319e-02, -5.82484007e-02, -2.34951079e-02,
#        -2.14584097e-02,  5.65610491e-02,  1.04497619e-01, -5.46580888e-02,
#         9.19313282e-02, -1.23116346e-02,  5.65489456e-02, -1.06210103e-02],
#       dtype=float32)}

# %%
# Aggregate embeddings by averaging
final_vector = np.mean(list(label_embeddings.values()), axis=0)
print("Final Word2Vec Vector Shape:", final_vector.shape)
# Out:
# Final Word2Vec Vector Shape: (300,)

# %%
# Aggregate embeddings by averaging
final_vector = np.mean(list(label_embeddings_b.values()), axis=0)
print("Final BERT Vector Shape:", final_vector.shape)
# Out:
# Final BERT Vector Shape: (384,)
