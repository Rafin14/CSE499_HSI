# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tensorflow.keras import models, layers, regularizers

# %%
config = tf.compat.v1.ConfigProto(gpu_options =
                         tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8)
)

config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)

physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
# Out:
# WARNING:tensorflow:From C:\Users\rafin\AppData\Local\Temp\ipykernel_10500\717319033.py:7: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Num GPUs Available:  1

# %%
data = np.load('Blueberry.npy', allow_pickle= True)
labels = np.load('Blueberry_labels.npy', allow_pickle= True)

data.shape, labels.shape
# Out:
# ((4190, 32, 32, 462), (4190,))

# %%
mean = data.mean(axis=(0, 1, 2), keepdims=True)
std_dev = data.std(axis=(0, 1, 2), keepdims=True)

# Z-score normalization
data = (data - mean) / std_dev

print("Dataset shape:", data.shape)
# Out:
# Dataset shape: (4190, 32, 32, 462)

# %%
# Split data into training, validation, and testing sets
data_train, data_test, train_labels, test_labels = train_test_split(data, labels, test_size = 0.25, random_state = 42, stratify = labels)

data_train.shape, train_labels.shape, data_test.shape, test_labels.shape
# Out:
# ((3142, 32, 32, 462), (3142,), (1048, 32, 32, 462), (1048,))

# %%
'''
# Save the reshaped training and testing data as .npy files
np.save('train_labels.npy', train_labels)
np.save('test_labels.npy', test_labels)
'''

# %% [markdown]
# PCA

# %%
#PCA START
hsi_image_train = data_train
hsi_image_test = data_test

# Reshape to (264 * 1024, 320)
hsi_reshaped_train = hsi_image_train.reshape(-1, 462)
hsi_reshaped_test = hsi_image_test.reshape(-1, 462)

hsi_reshaped_train.shape, hsi_reshaped_test.shape
# Out:
# ((3217408, 462), (1073152, 462))

# %%
# Apply PCA
pca = PCA()
hsi_train_pca = pca.fit_transform(hsi_reshaped_train)

explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance)

# %%
plt.figure(figsize=(5, 5))
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--')
plt.xlabel('Number of Dimensions')
plt.ylabel('Total Variance Retained')
plt.title('Variance Retained vs No. of Dimensions')
plt.grid()
plt.show()

# %%
#No. of Dimensions that retains 95% varinace:
optimal_components = np.argmax(cumulative_explained_variance >= 0.999) + 1 
print(f"Number of Dimensions to retain 99% variance: {optimal_components}")

pca = PCA(n_components=optimal_components)

X_train_PCA = pca.fit_transform(hsi_reshaped_train)
X_test_pca = pca.transform(hsi_reshaped_test)

X_train_PCA.shape, X_test_pca.shape
# Out:
# Number of Dimensions to retain 99% variance: 231
# ((3217408, 231), (1073152, 231))

# %%
# Reshape back to the spatial dimensions
data_train = X_train_PCA.reshape(3142, 32, 32, optimal_components)
data_test = X_test_pca.reshape(1048, 32, 32, optimal_components)

data_train.shape, data_test.shape
# Out:
# ((3142, 32, 32, 231), (1048, 32, 32, 231))

# %%
#SAVE PCA Training and Testing set
'''
# Save the reshaped training and testing data as .npy files
np.save('data_train_PCA.npy', data_train)
np.save('data_test_PCA.npy', data_test)
'''

# %% [markdown]
# LOAD and USE PCA DATA

# %%
#LOAD PCA DATA
data_train = np.load('data_train_PCA.npy')
data_test = np.load('data_test_PCA.npy')

train_labels = np.load('train_labels.npy')
test_labels = np.load('test_labels.npy')

print(data_train.shape, data_test.shape, train_labels.shape, test_labels.shape )
# Out:
# (3142, 32, 32, 231) (1048, 32, 32, 231) (3142,) (1048,)

# %%
le= LabelEncoder()
y_train = le.fit_transform(train_labels)

le2= LabelEncoder()
y_test= le2.fit_transform(test_labels)

# %%
# Add channel dimension to data
data_train = data_train[..., np.newaxis]
data_test = data_test[..., np.newaxis]

data_train.shape, data_test.shape
# Out:
# ((3142, 32, 32, 231, 1), (1048, 32, 32, 231, 1))

# %%
def augment_data(sample, label):
    
    # Ensure both are the same type
    random_scale = tf.cast(tf.random.uniform([], 0.9, 1.1), dtype=sample.dtype)
    sample = sample * random_scale  # Random scale between 0.9 and 1.1
    
    return sample, label

# %%
# Convert data to TensorFlow dataset

train_dataset = tf.data.Dataset.from_tensor_slices((data_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((data_test, y_test))

# Apply augmentation only on training data
train_dataset = train_dataset.map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle, batch, and prefetch
batch_size = 4

train_dataset = train_dataset.shuffle(buffer_size=100).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
tf.random.set_seed(1234)

input_shape = (32, 32, 231, 1)

model = models.Sequential([
    
    
    #1st Conv Layer
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.01), input_shape=input_shape),
    #layers.BatchNormalization(),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3
     
     
     
    #2nd Conv Layer
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.001)),
    #layers.BatchNormalization(),
    
    
    
    #3rd Conv Layer
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.0001)),
    #layers.BatchNormalization(),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3


    layers.Flatten(),
    
    
    #1st FC layer
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),  # Dropout with a rate of 0.5
    #layers.BatchNormalization(),
    
    
    
    #2nd FC layer
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
    layers.Dense(2, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 30, 229, 32)   896
#
#  average_pooling3d (AverageP  (None, 15, 15, 114, 32)  0
#  ooling3D)
#
#  conv3d_1 (Conv3D)           (None, 13, 13, 112, 64)   55360
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 110, 128)  221312
#
#  average_pooling3d_1 (Averag  (None, 5, 5, 55, 128)    0
#  ePooling3D)
#
#  flatten (Flatten)           (None, 176000)            0
#
#  dense (Dense)               (None, 128)               22528128
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 22,814,082
# Trainable params: 22,814,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define the callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = 'best_model_blueberry.h5',            # Path to save the best model
    monitor = 'accuracy',                   # Metric to monitor
    save_best_only = True,                 # Save only the best model
    save_weights_only = False,             # Save the entire model (architecture + weights)
    mode = 'max',                          # Mode 'max' because we want to maximize accuracy
    verbose = 1
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'loss',
    patience = 15,
    restore_best_weights = True
)

# Train the model with the callbacks
history = model.fit(
    train_dataset,
    epochs = 100,
    validation_data = test_dataset,
    callbacks = [checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 786/786 [==============================] - ETA: 0s - loss: 0.6823 - accuracy: 0.6439
# Epoch 1: accuracy improved from -inf to 0.64386, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 69s 78ms/step - loss: 0.6823 - accuracy: 0.6439 - val_loss: 0.5622 - val_accuracy: 0.7557
# Epoch 2/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.5862 - accuracy: 0.7086
# Epoch 2: accuracy improved from 0.64386 to 0.70847, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 60s 77ms/step - loss: 0.5863 - accuracy: 0.7085 - val_loss: 0.5583 - val_accuracy: 0.7433
# Epoch 3/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.5601 - accuracy: 0.7376
# Epoch 3: accuracy improved from 0.70847 to 0.73743, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 61s 77ms/step - loss: 0.5602 - accuracy: 0.7374 - val_loss: 0.5117 - val_accuracy: 0.7700
# Epoch 4/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.7691
# Epoch 4: accuracy improved from 0.73743 to 0.76894, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 61s 78ms/step - loss: 0.5348 - accuracy: 0.7689 - val_loss: 0.4413 - val_accuracy: 0.8578
# Epoch 5/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.4881 - accuracy: 0.8143
# Epoch 5: accuracy improved from 0.76894 to 0.81413, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 61s 78ms/step - loss: 0.4884 - accuracy: 0.8141 - val_loss: 0.4105 - val_accuracy: 0.8769
# Epoch 6/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.4541 - accuracy: 0.8411
# Epoch 6: accuracy improved from 0.81413 to 0.84118, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 61s 78ms/step - loss: 0.4538 - accuracy: 0.8412 - val_loss: 0.3835 - val_accuracy: 0.8893
# Epoch 7/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.4387 - accuracy: 0.8455
# Epoch 7: accuracy improved from 0.84118 to 0.84564, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 61s 78ms/step - loss: 0.4386 - accuracy: 0.8456 - val_loss: 0.4213 - val_accuracy: 0.8569
# Epoch 8/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.4226 - accuracy: 0.8589
# Epoch 8: accuracy improved from 0.84564 to 0.85901, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 61s 78ms/step - loss: 0.4224 - accuracy: 0.8590 - val_loss: 0.3794 - val_accuracy: 0.8779
# Epoch 9/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.4301 - accuracy: 0.8548
# Epoch 9: accuracy did not improve from 0.85901
# 786/786 [==============================] - 61s 77ms/step - loss: 0.4300 - accuracy: 0.8549 - val_loss: 0.3712 - val_accuracy: 0.8845
# Epoch 10/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.4041 - accuracy: 0.8624
# Epoch 10: accuracy improved from 0.85901 to 0.86219, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 61s 78ms/step - loss: 0.4042 - accuracy: 0.8622 - val_loss: 0.3620 - val_accuracy: 0.8960
# Epoch 11/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3942 - accuracy: 0.8669
# Epoch 11: accuracy improved from 0.86219 to 0.86696, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 61s 78ms/step - loss: 0.3940 - accuracy: 0.8670 - val_loss: 0.3687 - val_accuracy: 0.8960
# Epoch 12/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3875 - accuracy: 0.8710
# Epoch 12: accuracy improved from 0.86696 to 0.87110, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 62s 78ms/step - loss: 0.3874 - accuracy: 0.8711 - val_loss: 0.3641 - val_accuracy: 0.8903
# Epoch 13/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3802 - accuracy: 0.8815
# Epoch 13: accuracy improved from 0.87110 to 0.88160, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 63s 80ms/step - loss: 0.3800 - accuracy: 0.8816 - val_loss: 0.3858 - val_accuracy: 0.8750
# Epoch 14/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3782 - accuracy: 0.8774
# Epoch 14: accuracy did not improve from 0.88160
# 786/786 [==============================] - 63s 80ms/step - loss: 0.3781 - accuracy: 0.8775 - val_loss: 0.4284 - val_accuracy: 0.8540
# Epoch 15/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3694 - accuracy: 0.8815
# Epoch 15: accuracy did not improve from 0.88160
# 786/786 [==============================] - 63s 80ms/step - loss: 0.3693 - accuracy: 0.8816 - val_loss: 0.3725 - val_accuracy: 0.8865
# Epoch 16/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3670 - accuracy: 0.8790
# Epoch 16: accuracy did not improve from 0.88160
# 786/786 [==============================] - 62s 79ms/step - loss: 0.3669 - accuracy: 0.8791 - val_loss: 0.3810 - val_accuracy: 0.8884
# Epoch 17/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3680 - accuracy: 0.8818
# Epoch 17: accuracy improved from 0.88160 to 0.88192, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 63s 80ms/step - loss: 0.3680 - accuracy: 0.8819 - val_loss: 0.3808 - val_accuracy: 0.8779
# Epoch 18/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3624 - accuracy: 0.8847
# Epoch 18: accuracy improved from 0.88192 to 0.88479, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 63s 80ms/step - loss: 0.3623 - accuracy: 0.8848 - val_loss: 0.3815 - val_accuracy: 0.8788
# Epoch 19/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3633 - accuracy: 0.8889
# Epoch 19: accuracy improved from 0.88479 to 0.88892, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 63s 80ms/step - loss: 0.3633 - accuracy: 0.8889 - val_loss: 0.3785 - val_accuracy: 0.8922
# Epoch 20/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3690 - accuracy: 0.8857
# Epoch 20: accuracy did not improve from 0.88892
# 786/786 [==============================] - 63s 80ms/step - loss: 0.3688 - accuracy: 0.8857 - val_loss: 0.3672 - val_accuracy: 0.8960
# Epoch 21/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3496 - accuracy: 0.8943
# Epoch 21: accuracy improved from 0.88892 to 0.89433, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 63s 80ms/step - loss: 0.3495 - accuracy: 0.8943 - val_loss: 0.3921 - val_accuracy: 0.8912
# Epoch 22/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3455 - accuracy: 0.8990
# Epoch 22: accuracy improved from 0.89433 to 0.89911, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 63s 80ms/step - loss: 0.3454 - accuracy: 0.8991 - val_loss: 0.3854 - val_accuracy: 0.8817
# Epoch 23/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3523 - accuracy: 0.8975
# Epoch 23: accuracy did not improve from 0.89911
# 786/786 [==============================] - 63s 80ms/step - loss: 0.3524 - accuracy: 0.8975 - val_loss: 0.3887 - val_accuracy: 0.8893
# Epoch 24/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3616 - accuracy: 0.8908
# Epoch 24: accuracy did not improve from 0.89911
# 786/786 [==============================] - 63s 81ms/step - loss: 0.3616 - accuracy: 0.8908 - val_loss: 0.4261 - val_accuracy: 0.8683
# Epoch 25/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3390 - accuracy: 0.9019
# Epoch 25: accuracy improved from 0.89911 to 0.90166, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 63s 80ms/step - loss: 0.3391 - accuracy: 0.9017 - val_loss: 0.3973 - val_accuracy: 0.8826
# Epoch 26/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3475 - accuracy: 0.9003
# Epoch 26: accuracy did not improve from 0.90166
# 786/786 [==============================] - 62s 78ms/step - loss: 0.3474 - accuracy: 0.9004 - val_loss: 0.4220 - val_accuracy: 0.8712
# Epoch 27/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3323 - accuracy: 0.9054
# Epoch 27: accuracy improved from 0.90166 to 0.90547, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 60s 76ms/step - loss: 0.3322 - accuracy: 0.9055 - val_loss: 0.4353 - val_accuracy: 0.8845
# Epoch 28/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3363 - accuracy: 0.9054
# Epoch 28: accuracy did not improve from 0.90547
# 786/786 [==============================] - 59s 76ms/step - loss: 0.3366 - accuracy: 0.9052 - val_loss: 0.3942 - val_accuracy: 0.8893
# Epoch 29/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3233 - accuracy: 0.9131
# Epoch 29: accuracy improved from 0.90547 to 0.91311, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 62s 79ms/step - loss: 0.3233 - accuracy: 0.9131 - val_loss: 0.4296 - val_accuracy: 0.8855
# Epoch 30/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3452 - accuracy: 0.9032
# Epoch 30: accuracy did not improve from 0.91311
# 786/786 [==============================] - 61s 78ms/step - loss: 0.3451 - accuracy: 0.9032 - val_loss: 0.4109 - val_accuracy: 0.8807
# Epoch 31/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3355 - accuracy: 0.9102
# Epoch 31: accuracy did not improve from 0.91311
# 786/786 [==============================] - 62s 78ms/step - loss: 0.3354 - accuracy: 0.9102 - val_loss: 0.4046 - val_accuracy: 0.8769
# Epoch 32/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3323 - accuracy: 0.9076
# Epoch 32: accuracy did not improve from 0.91311
# 786/786 [==============================] - 62s 78ms/step - loss: 0.3322 - accuracy: 0.9077 - val_loss: 0.3945 - val_accuracy: 0.8903
# Epoch 33/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3535 - accuracy: 0.9013
# Epoch 33: accuracy did not improve from 0.91311
# 786/786 [==============================] - 62s 78ms/step - loss: 0.3534 - accuracy: 0.9013 - val_loss: 0.4052 - val_accuracy: 0.8826
# Epoch 34/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3291 - accuracy: 0.9096
# Epoch 34: accuracy did not improve from 0.91311
# 786/786 [==============================] - 62s 78ms/step - loss: 0.3290 - accuracy: 0.9096 - val_loss: 0.3880 - val_accuracy: 0.8922
# Epoch 35/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3342 - accuracy: 0.9108
# Epoch 35: accuracy did not improve from 0.91311
# 786/786 [==============================] - 61s 78ms/step - loss: 0.3340 - accuracy: 0.9109 - val_loss: 0.4233 - val_accuracy: 0.8874
# Epoch 36/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3275 - accuracy: 0.9178
# Epoch 36: accuracy improved from 0.91311 to 0.91789, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 62s 79ms/step - loss: 0.3274 - accuracy: 0.9179 - val_loss: 0.4064 - val_accuracy: 0.8893
# Epoch 37/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3271 - accuracy: 0.9188
# Epoch 37: accuracy improved from 0.91789 to 0.91852, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 62s 79ms/step - loss: 0.3281 - accuracy: 0.9185 - val_loss: 0.4275 - val_accuracy: 0.8750
# Epoch 38/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3360 - accuracy: 0.9150
# Epoch 38: accuracy did not improve from 0.91852
# 786/786 [==============================] - 61s 78ms/step - loss: 0.3359 - accuracy: 0.9150 - val_loss: 0.4403 - val_accuracy: 0.8779
# Epoch 39/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3396 - accuracy: 0.9118
# Epoch 39: accuracy did not improve from 0.91852
# 786/786 [==============================] - 59s 76ms/step - loss: 0.3395 - accuracy: 0.9118 - val_loss: 0.4381 - val_accuracy: 0.8874
# Epoch 40/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3192 - accuracy: 0.9194
# Epoch 40: accuracy improved from 0.91852 to 0.91948, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 60s 76ms/step - loss: 0.3191 - accuracy: 0.9195 - val_loss: 0.4165 - val_accuracy: 0.8845
# Epoch 41/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.
100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3185 - accuracy: 0.9261
# Epoch 74: accuracy did not improve from 0.93571
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3185 - accuracy: 0.9262 - val_loss: 0.4497 - val_accuracy: 0.8712
# Epoch 75/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3043 - accuracy: 0.9287
# Epoch 75: accuracy did not improve from 0.93571
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3042 - accuracy: 0.9287 - val_loss: 0.5567 - val_accuracy: 0.8540
# Epoch 76/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3051 - accuracy: 0.9328
# Epoch 76: accuracy did not improve from 0.93571
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3050 - accuracy: 0.9328 - val_loss: 0.4717 - val_accuracy: 0.8769
# Epoch 77/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.2921 - accuracy: 0.9357
# Epoch 77: accuracy did not improve from 0.93571
# 786/786 [==============================] - 59s 75ms/step - loss: 0.2920 - accuracy: 0.9357 - val_loss: 0.4469 - val_accuracy: 0.8798
# Epoch 78/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3061 - accuracy: 0.9299
# Epoch 78: accuracy did not improve from 0.93571
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3064 - accuracy: 0.9297 - val_loss: 0.5023 - val_accuracy: 0.8521
# Epoch 79/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.2988 - accuracy: 0.9357
# Epoch 79: accuracy did not improve from 0.93571
# 786/786 [==============================] - 59s 75ms/step - loss: 0.2987 - accuracy: 0.9357 - val_loss: 0.4468 - val_accuracy: 0.8807
# Epoch 80/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3080 - accuracy: 0.9322
# Epoch 80: accuracy did not improve from 0.93571
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3080 - accuracy: 0.9322 - val_loss: 0.5193 - val_accuracy: 0.8607
# Epoch 81/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.2876 - accuracy: 0.9366
# Epoch 81: accuracy improved from 0.93571 to 0.93666, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 59s 76ms/step - loss: 0.2878 - accuracy: 0.9367 - val_loss: 0.5145 - val_accuracy: 0.8597
# Epoch 82/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3304 - accuracy: 0.9197
# Epoch 82: accuracy did not improve from 0.93666
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3303 - accuracy: 0.9198 - val_loss: 0.4580 - val_accuracy: 0.8597
# Epoch 83/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.2928 - accuracy: 0.9392
# Epoch 83: accuracy improved from 0.93666 to 0.93921, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 59s 76ms/step - loss: 0.2928 - accuracy: 0.9392 - val_loss: 0.4597 - val_accuracy: 0.8836
# Epoch 84/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.2974 - accuracy: 0.9325
# Epoch 84: accuracy did not improve from 0.93921
# 786/786 [==============================] - 59s 75ms/step - loss: 0.2973 - accuracy: 0.9325 - val_loss: 0.5819 - val_accuracy: 0.8588
# Epoch 85/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3050 - accuracy: 0.9338
# Epoch 85: accuracy did not improve from 0.93921
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3049 - accuracy: 0.9338 - val_loss: 0.5016 - val_accuracy: 0.8760
# Epoch 86/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.2959 - accuracy: 0.9360
# Epoch 86: accuracy did not improve from 0.93921
# 786/786 [==============================] - 59s 75ms/step - loss: 0.2958 - accuracy: 0.9360 - val_loss: 0.5846 - val_accuracy: 0.8321
# Epoch 87/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3110 - accuracy: 0.9287
# Epoch 87: accuracy did not improve from 0.93921
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3110 - accuracy: 0.9287 - val_loss: 0.4773 - val_accuracy: 0.8807
# Epoch 88/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3080 - accuracy: 0.9268
# Epoch 88: accuracy did not improve from 0.93921
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3079 - accuracy: 0.9268 - val_loss: 0.4673 - val_accuracy: 0.8807
# Epoch 89/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3023 - accuracy: 0.9328
# Epoch 89: accuracy did not improve from 0.93921
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3022 - accuracy: 0.9328 - val_loss: 0.5020 - val_accuracy: 0.8664
# Epoch 90/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.2930 - accuracy: 0.9385
# Epoch 90: accuracy did not improve from 0.93921
# 786/786 [==============================] - 59s 75ms/step - loss: 0.2929 - accuracy: 0.9386 - val_loss: 0.5774 - val_accuracy: 0.8559
# Epoch 91/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3217 - accuracy: 0.9325
# Epoch 91: accuracy did not improve from 0.93921
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3221 - accuracy: 0.9322 - val_loss: 0.4829 - val_accuracy: 0.8674
# Epoch 92/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.2766 - accuracy: 0.9487
# Epoch 92: accuracy improved from 0.93921 to 0.94876, saving model to best_model_blueberry.h5
# 786/786 [==============================] - 59s 76ms/step - loss: 0.2765 - accuracy: 0.9488 - val_loss: 0.5348 - val_accuracy: 0.8740
# Epoch 93/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.2942 - accuracy: 0.9379
# Epoch 93: accuracy did not improve from 0.94876
# 786/786 [==============================] - 59s 75ms/step - loss: 0.2952 - accuracy: 0.9376 - val_loss: 0.5436 - val_accuracy: 0.8607
# Epoch 94/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3099 - accuracy: 0.9318
# Epoch 94: accuracy did not improve from 0.94876
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3098 - accuracy: 0.9319 - val_loss: 0.5069 - val_accuracy: 0.8731
# Epoch 95/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3053 - accuracy: 0.9347
# Epoch 95: accuracy did not improve from 0.94876
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3053 - accuracy: 0.9348 - val_loss: 0.4845 - val_accuracy: 0.8721
# Epoch 96/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3002 - accuracy: 0.9382
# Epoch 96: accuracy did not improve from 0.94876
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3002 - accuracy: 0.9383 - val_loss: 0.5383 - val_accuracy: 0.8597
# Epoch 97/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.2963 - accuracy: 0.9354
# Epoch 97: accuracy did not improve from 0.94876
# 786/786 [==============================] - 59s 75ms/step - loss: 0.2963 - accuracy: 0.9354 - val_loss: 0.4573 - val_accuracy: 0.8798
# Epoch 98/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.2909 - accuracy: 0.9389
# Epoch 98: accuracy did not improve from 0.94876
# 786/786 [==============================] - 59s 75ms/step - loss: 0.2909 - accuracy: 0.9389 - val_loss: 0.5075 - val_accuracy: 0.8492
# Epoch 99/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3018 - accuracy: 0.9312
# Epoch 99: accuracy did not improve from 0.94876
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3017 - accuracy: 0.9313 - val_loss: 0.5618 - val_accuracy: 0.8578
# Epoch 100/100
# 785/786 [============================>.] - ETA: 0s - loss: 0.3048 - accuracy: 0.9366
# Epoch 100: accuracy did not improve from 0.94876
# 786/786 [==============================] - 59s 75ms/step - loss: 0.3047 - accuracy: 0.9367 - val_loss: 0.5963 - val_accuracy: 0.8588

# %%
# Plot training & validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Get true labels and predictions
test_labels = np.concatenate([y for x, y in test_dataset], axis=0)
predictions = np.argmax(model.predict(test_dataset), axis=-1)
# Out:
# 262/262 [==============================] - 6s 21ms/step

# %%
# Classification report
print("Classification Report:")
print(classification_report(test_labels, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85       523
#            1       0.83      0.91      0.87       525
#
#     accuracy                           0.86      1048
#    macro avg       0.86      0.86      0.86      1048
# weighted avg       0.86      0.86      0.86      1048

# %%
# Confusion matrix
conf_matrix = confusion_matrix(test_labels, predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(2)], yticklabels=[str(i) for i in range(2)])

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
