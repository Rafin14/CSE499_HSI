# %%
import os
import numpy as np
import rasterio
import matplotlib.pyplot as plt

# %%
input_directory = 'D:/CSE499A/Datasets/ButterFly/masked_datacube_30'
output_directory = 'masked_datacube_30_npy'


# Ensure output directory exists
if not os.path.exists(output_directory):
    
    os.makedirs(output_directory)

# Loop through all files in the directory
for root, dirs, files in os.walk(input_directory):
    
    for file in files:
        
        if file.endswith('.bil'):
            
            
            bil_file_path = os.path.join(root, file)
            
            # Read the .bil file
            with rasterio.open(bil_file_path) as dataset:
                
                # Read all bands 
                array = dataset.read()  

            relative_path = os.path.relpath(root, input_directory)
            output_folder = os.path.join(output_directory, relative_path)

            if not os.path.exists(output_folder):
                
                os.makedirs(output_folder)

            # Create a single output file path for all bands
            output_file_path = os.path.join(output_folder, file.replace('.bil', '.npy'))

            # Save as .npy file
            np.save(output_file_path, array)

            print(f"Saved {output_file_path}")
# Out:
# c:\Users\rafin\AppData\Local\Programs\Python\Python310\lib\site-packages\rasterio\__init__.py:317: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_1.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_10.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_11.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_12.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_13.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_14.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_15.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_16.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_17.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_18.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_19.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_2.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_20.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_21.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_22.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_23.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_24.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_25.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_26.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_27.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_28.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_29.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_3.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_30.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_4.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_5.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_6.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_7.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_8.npy
# Saved masked_datacube_30_bil\AE\espece10_acq1_cube_9.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_1.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_10.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_11.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_12.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_13.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_14.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_15.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_16.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_17.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_18.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_19.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_2.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_20.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_21.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_22.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_23.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_24.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_25.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_26.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_27.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_28.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_29.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_3.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_30.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_4.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_5.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_6.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_7.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_8.npy
# Saved masked_datacube_30_bil\AE\espece10_acq4_cube_9.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_1.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_10.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_11.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_12.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_13.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_14.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_15.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_16.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_17.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_18.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_19.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_2.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_20.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_21.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_22.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_23.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_24.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_25.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_26.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_27.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_28.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_29.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_3.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_30.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_4.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_5.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_6.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_7.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_8.npy
# Saved masked_datacube_30_bil\AO\espece7_acq10_cube_9.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_1.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_10.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_11.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_12.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_13.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_14.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_15.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_16.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_17.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_18.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_19.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_2.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_20.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_21.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_22.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_23.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_24.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_25.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_26.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_27.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_28.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_29.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_3.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_30.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_4.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_5.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_6.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_7.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_8.npy
# Saved masked_datacube_30_bil\AO\espece7_acq11_cube_9.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_1.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_10.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_11.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_12.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_13.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_14.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_15.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_16.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_17.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_18.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_19.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_2.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_20.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_21.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_22.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_23.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_24.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_25.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_26.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_27.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_28.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_29.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_3.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_30.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_4.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_5.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_6.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_7.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_8.npy
# Saved masked_datacube_30_bil\DC\espece4_acq4_cube_9.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_1.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_10.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_11.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_12.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_13.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_14.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_15.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_16.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_17.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_18.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_19.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_2.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_20.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_21.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_22.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_23.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_24.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_25.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_26.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_27.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_28.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_29.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_3.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_30.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_4.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_5.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_6.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_7.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_8.npy
# Saved masked_datacube_30_bil\DC\espece4_acq6_cube_9.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_1.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_10.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_11.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_12.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_13.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_14.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_15.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_16.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_17.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_18.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_19.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_2.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_20.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_21.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_22.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_23.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_24.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_25.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_26.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_27.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_28.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_29.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_3.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_30.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_4.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_5.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_6.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_7.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_8.npy
# Saved masked_datacube_30_bil\HM\espece1_acq3_cube_9.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_1.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_10.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_11.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_12.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_13.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_14.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_15.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_16.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_17.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_18.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_19.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_2.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_20.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_21.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_22.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_23.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_24.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_25.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_26.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_27.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_28.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_29.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_3.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_30.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_4.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_5.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_6.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_7.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_8.npy
# Saved masked_datacube_30_bil\HM\espece1_acq4_cube_9.npy
