# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tensorflow.keras import models, layers, regularizers

# %%
config = tf.compat.v1.ConfigProto(gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
physical_devices = tf.config.experimental.list_physical_devices('GPU')

print("Num GPUs Available: ", len(physical_devices))
# Out:
# WARNING:tensorflow:From C:\Users\rafin\AppData\Local\Temp\ipykernel_14068\3036340341.py:4: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Num GPUs Available:  1

# %%
data_train = np.load('Datasets/Wood_train.npy', allow_pickle= True)
data_test = np.load('Datasets/Wood_test.npy', allow_pickle= True)

train_labels = np.load('Datasets/Wood_train_labels.npy', allow_pickle= True)
test_labels = np.load('Datasets/Wood_test_labels.npy', allow_pickle= True)

data_train.shape, train_labels.shape, data_test.shape, test_labels.shape
# Out:
# ((264, 32, 32, 320), (264,), (132, 32, 32, 320), (132,))

# %%
mean = data_train.mean(axis=(0, 1, 2), keepdims=True)
std_dev = data_train.std(axis=(0, 1, 2), keepdims=True)

# Z-score normalization
data_train = (data_train - mean) / std_dev

data_test = (data_test - mean) / std_dev

print("Train Shape:", data_train.shape)
print("Test Shape:", data_test.shape)
# Out:
# Train Shape: (264, 32, 32, 320)
# Test Shape: (132, 32, 32, 320)

# %%
hsi_image_train = data_train
hsi_image_test = data_test

hsi_reshaped_train = hsi_image_train.reshape(-1, 320)
hsi_reshaped_test = hsi_image_test.reshape(-1, 320)

hsi_reshaped_train.shape, hsi_reshaped_test.shape
# Out:
# ((270336, 320), (135168, 320))

# %%
# Apply PCA
pca = PCA()
hsi_train_pca = pca.fit_transform(hsi_reshaped_train)

explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance)

# %%
plt.figure(figsize=(5, 5))
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--')
plt.xlabel('Number of Dimensions')
plt.ylabel('Total Variance Retained')
plt.title('Variance Retained vs No. of Dimensions')
plt.grid()
plt.show()

# %%
#No. of Dimensions that retains 95% varinace:
optimal_components = np.argmax(cumulative_explained_variance >= 0.99) + 1 
print(f"Number of Dimensions to retain 99% variance: {optimal_components}")

pca = PCA(n_components=optimal_components)

X_train_PCA = pca.fit_transform(hsi_reshaped_train)
X_test_pca = pca.transform(hsi_reshaped_test)

X_train_PCA.shape, X_test_pca.shape
# Out:
# Number of Dimensions to retain 99% variance: 199
# ((270336, 199), (135168, 199))

# %%
# Reshape back to the spatial dimensions
data_train = X_train_PCA.reshape(264, 32, 32, optimal_components)
data_test = X_test_pca.reshape(132, 32, 32, optimal_components)

data_train.shape, data_test.shape
# Out:
# ((264, 32, 32, 199), (132, 32, 32, 199))

# %%
# Add channel dimension to data
data_train = data_train[..., np.newaxis]
data_test = data_test[..., np.newaxis]

data_train.shape, data_test.shape
# Out:
# ((264, 32, 32, 199, 1), (132, 32, 32, 199, 1))

# %%
le= LabelEncoder()
y_train = le.fit_transform(train_labels)

le2= LabelEncoder()
y_test= le2.fit_transform(test_labels)

# %%
def augment_data(sample, label):
    
    # Random flip along different axes
    sample = tf.image.random_flip_left_right(sample)
    sample = tf.image.random_flip_up_down(sample)

    # Random rotation
    sample = tf.image.rot90(sample, k=np.random.randint(1, 4))  # k=1 to 3 random rotations of 90°

    # Random intensity scaling (brightness variation)
    sample = sample * tf.random.uniform([], 0.9, 1.1)  # Random scale between 0.9 and 1.1
    
    return sample, label

# %%
# Convert data to TensorFlow dataset

train_dataset = tf.data.Dataset.from_tensor_slices((data_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((data_test, y_test))

# Apply augmentation only on training data
train_dataset = train_dataset.map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle, batch, and prefetch
batch_size = 8

train_dataset = train_dataset.shuffle(buffer_size=100).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
tf.random.set_seed(1234)

'''

input_shape = (32, 32, 199, 1)

model = models.Sequential([
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu', input_shape=input_shape),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Flatten(),
    
    layers.Dense(128, activation='relu'),
    layers.Dense(2, activation='sigmoid')
])

model.summary()

'''

input_shape = (32, 32, 199, 1)

model = models.Sequential([
    
    
    #1st Conv Layer
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.01), input_shape=input_shape),
    #layers.BatchNormalization(),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3
     
     
     
    #2nd Conv Layer
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.001)),
    #layers.BatchNormalization(),
    
    
    
    #3rd Conv Layer
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.0001)),
    #layers.BatchNormalization(),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3


    layers.Flatten(),
    
    
    #1st FC layer
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),  # Dropout with a rate of 0.5
    #layers.BatchNormalization(),
    
    
    
    #2nd FC layer
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
    layers.Dense(2, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 30, 197, 32)   896
#
#  average_pooling3d (AverageP  (None, 15, 15, 98, 32)   0
#  ooling3D)
#
#  conv3d_1 (Conv3D)           (None, 13, 13, 96, 64)    55360
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 94, 128)   221312
#
#  average_pooling3d_1 (Averag  (None, 5, 5, 47, 128)    0
#  ePooling3D)
#
#  flatten (Flatten)           (None, 150400)            0
#
#  dense (Dense)               (None, 128)               19251328
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 19,537,282
# Trainable params: 19,537,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define the callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = 'best_model_test.h5',    
    monitor = 'val_accuracy',          
    save_best_only = True,              
    save_weights_only = False,             
    mode = 'max',                          
    verbose = 1
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'loss',
    patience = 15,
    restore_best_weights = True
)

# Train the model with the callbacks
history = model.fit(
    train_dataset,
    epochs = 100,
    validation_data = test_dataset,
    callbacks = [checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 33/33 [==============================] - ETA: 0s - loss: 1.9557 - accuracy: 0.7273
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to best_model_test.h5
# 33/33 [==============================] - 18s 174ms/step - loss: 1.9557 - accuracy: 0.7273 - val_loss: 1.2417 - val_accuracy: 0.5000
# Epoch 2/100
# 33/33 [==============================] - ETA: 0s - loss: 0.9984 - accuracy: 0.3333
# Epoch 2: val_accuracy did not improve from 0.50000
# 33/33 [==============================] - 5s 155ms/step - loss: 0.9984 - accuracy: 0.3333 - val_loss: 0.8749 - val_accuracy: 0.5000
# Epoch 3/100
# 33/33 [==============================] - ETA: 0s - loss: 0.9151 - accuracy: 0.6174
# Epoch 3: val_accuracy improved from 0.50000 to 0.51515, saving model to best_model_test.h5
# 33/33 [==============================] - 6s 166ms/step - loss: 0.9151 - accuracy: 0.6174 - val_loss: 0.8822 - val_accuracy: 0.5152
# Epoch 4/100
# 33/33 [==============================] - ETA: 0s - loss: 0.8416 - accuracy: 0.4583
# Epoch 4: val_accuracy improved from 0.51515 to 0.87879, saving model to best_model_test.h5
# 33/33 [==============================] - 6s 166ms/step - loss: 0.8416 - accuracy: 0.4583 - val_loss: 0.6240 - val_accuracy: 0.8788
# Epoch 5/100
# 33/33 [==============================] - ETA: 0s - loss: 0.6646 - accuracy: 0.7652
# Epoch 5: val_accuracy improved from 0.87879 to 0.90909, saving model to best_model_test.h5
# 33/33 [==============================] - 6s 167ms/step - loss: 0.6646 - accuracy: 0.7652 - val_loss: 0.4193 - val_accuracy: 0.9091
# Epoch 6/100
# 33/33 [==============================] - ETA: 0s - loss: 0.7589 - accuracy: 0.7424
# Epoch 6: val_accuracy did not improve from 0.90909
# 33/33 [==============================] - 5s 154ms/step - loss: 0.7589 - accuracy: 0.7424 - val_loss: 0.6113 - val_accuracy: 0.7576
# Epoch 7/100
# 33/33 [==============================] - ETA: 0s - loss: 0.7685 - accuracy: 0.7273
# Epoch 7: val_accuracy improved from 0.90909 to 0.93939, saving model to best_model_test.h5
# 33/33 [==============================] - 6s 165ms/step - loss: 0.7685 - accuracy: 0.7273 - val_loss: 0.4429 - val_accuracy: 0.9394
# Epoch 8/100
# 33/33 [==============================] - ETA: 0s - loss: 0.7528 - accuracy: 0.7159
# Epoch 8: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 154ms/step - loss: 0.7528 - accuracy: 0.7159 - val_loss: 0.5350 - val_accuracy: 0.8712
# Epoch 9/100
# 33/33 [==============================] - ETA: 0s - loss: 0.5671 - accuracy: 0.8030
# Epoch 9: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 155ms/step - loss: 0.5671 - accuracy: 0.8030 - val_loss: 0.5111 - val_accuracy: 0.9167
# Epoch 10/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4981 - accuracy: 0.8598
# Epoch 10: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 156ms/step - loss: 0.4981 - accuracy: 0.8598 - val_loss: 0.4051 - val_accuracy: 0.9318
# Epoch 11/100
# 33/33 [==============================] - ETA: 0s - loss: 0.5652 - accuracy: 0.8333
# Epoch 11: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 153ms/step - loss: 0.5652 - accuracy: 0.8333 - val_loss: 0.5404 - val_accuracy: 0.8939
# Epoch 12/100
# 33/33 [==============================] - ETA: 0s - loss: 0.5141 - accuracy: 0.8068
# Epoch 12: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 154ms/step - loss: 0.5141 - accuracy: 0.8068 - val_loss: 0.4665 - val_accuracy: 0.9318
# Epoch 13/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4421 - accuracy: 0.8333
# Epoch 13: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 155ms/step - loss: 0.4421 - accuracy: 0.8333 - val_loss: 0.7157 - val_accuracy: 0.9167
# Epoch 14/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4256 - accuracy: 0.8447
# Epoch 14: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 155ms/step - loss: 0.4256 - accuracy: 0.8447 - val_loss: 0.9222 - val_accuracy: 0.9015
# Epoch 15/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4872 - accuracy: 0.8485
# Epoch 15: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 153ms/step - loss: 0.4872 - accuracy: 0.8485 - val_loss: 0.5029 - val_accuracy: 0.9318
# Epoch 16/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4371 - accuracy: 0.8485
# Epoch 16: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 156ms/step - loss: 0.4371 - accuracy: 0.8485 - val_loss: 0.5843 - val_accuracy: 0.9242
# Epoch 17/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4669 - accuracy: 0.8220
# Epoch 17: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 153ms/step - loss: 0.4669 - accuracy: 0.8220 - val_loss: 0.6226 - val_accuracy: 0.9091
# Epoch 18/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4134 - accuracy: 0.8295
# Epoch 18: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 156ms/step - loss: 0.4134 - accuracy: 0.8295 - val_loss: 0.5801 - val_accuracy: 0.9167
# Epoch 19/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4237 - accuracy: 0.8674
# Epoch 19: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 154ms/step - loss: 0.4237 - accuracy: 0.8674 - val_loss: 0.5236 - val_accuracy: 0.9167
# Epoch 20/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3768 - accuracy: 0.8674
# Epoch 20: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 156ms/step - loss: 0.3768 - accuracy: 0.8674 - val_loss: 0.7943 - val_accuracy: 0.9242
# Epoch 21/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4452 - accuracy: 0.8561
# Epoch 21: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 155ms/step - loss: 0.4452 - accuracy: 0.8561 - val_loss: 0.6304 - val_accuracy: 0.9242
# Epoch 22/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3525 - accuracy: 0.8902
# Epoch 22: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 154ms/step - loss: 0.3525 - accuracy: 0.8902 - val_loss: 0.6288 - val_accuracy: 0.9242
# Epoch 23/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3184 - accuracy: 0.9129
# Epoch 23: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 156ms/step - loss: 0.3184 - accuracy: 0.9129 - val_loss: 0.9368 - val_accuracy: 0.9242
# Epoch 24/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3307 - accuracy: 0.8977
# Epoch 24: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 154ms/step - loss: 0.3307 - accuracy: 0.8977 - val_loss: 1.0349 - val_accuracy: 0.9318
# Epoch 25/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3484 - accuracy: 0.9394
# Epoch 25: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 154ms/step - loss: 0.3484 - accuracy: 0.9394 - val_loss: 0.8146 - val_accuracy: 0.9167
# Epoch 26/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3311 - accuracy: 0.9280
# Epoch 26: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 154ms/step - loss: 0.3311 - accuracy: 0.9280 - val_loss: 1.2156 - val_accuracy: 0.9015
# Epoch 27/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3818 - accuracy: 0.8977
# Epoch 27: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 155ms/step - loss: 0.3818 - accuracy: 0.8977 - val_loss: 0.7543 - val_accuracy: 0.7879
# Epoch 28/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3546 - accuracy: 0.9129
# Epoch 28: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 155ms/step - loss: 0.3546 - accuracy: 0.9129 - val_loss: 0.5675 - val_accuracy: 0.8939
# Epoch 29/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3459 - accuracy: 0.9167
# Epoch 29: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 156ms/step - loss: 0.3459 - accuracy: 0.9167 - val_loss: 0.4701 - val_accuracy: 0.8864
# Epoch 30/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2592 - accuracy: 0.9545
# Epoch 30: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 155ms/step - loss: 0.2592 - accuracy: 0.9545 - val_loss: 0.7894 - val_accuracy: 0.9394
# Epoch 31/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2793 - accuracy: 0.9280
# Epoch 31: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 155ms/step - loss: 0.2793 - accuracy: 0.9280 - val_loss: 0.5470 - val_accuracy: 0.8864
# Epoch 32/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.9432
# Epoch 32: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 156ms/step - loss: 0.2394 - accuracy: 0.9432 - val_loss: 1.0609 - val_accuracy: 0.9015
# Epoch 33/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2170 - accuracy: 0.9697
# Epoch 33: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 157ms/step - loss: 0.2170 - accuracy: 0.9697 - val_loss: 0.9998 - val_accuracy: 0.8712
# Epoch 34/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2111 - accuracy: 0.9773
# Epoch 34: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 154ms/step - loss: 0.2111 - accuracy: 0.9773 - val_loss: 0.9672 - val_accuracy: 0.9242
# Epoch 35/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.9583
# Epoch 35: val_accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 145ms/step - loss: 0.2708 - accuracy: 0.9583 - val_loss: 0.8658 - val_accuracy: 0.8106
# Epoch 36/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2130 - accuracy: 0.9773
# Epoch 36: val_accuracy improved from 0.93939 to 0.94697, saving model to best_model_test.h5
# 33/33 [==============================] - 5s 155ms/step - loss: 0.2130 - accuracy: 0.9773 - val_loss: 0.9915 - val_accuracy: 0.9470
# Epoch 37/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2282 - accuracy: 0.9735
# Epoch 37: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 143ms/step - loss: 0.2282 - accuracy: 0.9735 - val_loss: 1.3467 - val_accuracy: 0.9242
# Epoch 38/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2521 - accuracy: 0.9583
# Epoch 38: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.2521 - accuracy: 0.9583 - val_loss: 0.9083 - val_accuracy: 0.9167
# Epoch 39/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9848
# Epoch 39: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 146ms/step - loss: 0.1717 - accuracy: 0.9848 - val_loss: 1.2447 - val_accuracy: 0.9394
# Epoch 40/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2442 - accuracy: 0.9621
# Epoch 40: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.2442 - accuracy: 0.9621 - val_loss: 0.9213 - val_accuracy: 0.8333
# Epoch 41/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2064 - accuracy: 0.9621
# Epoch 41: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.2064 - accuracy: 0.9621 - val_loss: 0.9893 - val_accuracy: 0.8409
# Epoch 42/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1572 - accuracy: 0.9886
# Epoch 42: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 145ms/step - loss: 0.1572 - accuracy: 0.9886 - val_loss: 1.3572 - val_accuracy: 0.9470
# Epoch 43/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9621
# Epoch 43: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.2080 - accuracy: 0.9621 - val_loss: 0.8567 - val_accuracy: 0.9091
# Epoch 44/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.9583
# Epoch 44: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.2026 - accuracy: 0.9583 - val_loss: 1.4324 - val_accuracy: 0.7955
# Epoch 45/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9773
# Epoch 45: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.1731 - accuracy: 0.9773 - val_loss: 1.2206 - val_accuracy: 0.8712
# Epoch 46/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9962
# Epoch 46: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 146ms/step - loss: 0.1421 - accuracy: 0.9962 - val_loss: 1.4221 - val_accuracy: 0.9167
# Epoch 47/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1860 - accuracy: 0.9735
# Epoch 47: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.1860 - accuracy: 0.9735 - val_loss: 1.0207 - val_accuracy: 0.9470
# Epoch 48/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4150 - accuracy: 0.9091
# Epoch 48: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 145ms/step - loss: 0.4150 - accuracy: 0.9091 - val_loss: 0.7570 - val_accuracy: 0.9167
# Epoch 49/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.9545
# Epoch 49: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 143ms/step - loss: 0.3155 - accuracy: 0.9545 - val_loss: 0.8523 - val_accuracy: 0.8636
# Epoch 50/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9621
# Epoch 50: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.2430 - accuracy: 0.9621 - val_loss: 1.5728 - val_accuracy: 0.9394
# Epoch 51/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3089 - accuracy: 0.9773
# Epoch 51: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.3089 - accuracy: 0.9773 - val_loss: 1.0140 - val_accuracy: 0.8712
# Epoch 52/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9735
# Epoch 52: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.2175 - accuracy: 0.9735 - val_loss: 1.1267 - val_accuracy: 0.9091
# Epoch 53/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2047 - accuracy: 0.9659
# Epoch 53: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 145ms/step - loss: 0.2047 - accuracy: 0.9659 - val_loss: 1.7421 - val_accuracy: 0.8258
# Epoch 54/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2123 - accuracy: 0.9621
# Epoch 54: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 145ms/step - loss: 0.2123 - accuracy: 0.9621 - val_loss: 2.5520 - val_accuracy: 0.8712
# Epoch 55/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3582 - accuracy: 0.9318
# Epoch 55: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.3582 - accuracy: 0.9318 - val_loss: 0.7455 - val_accuracy: 0.7727
# Epoch 56/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3545 - accuracy: 0.9356
# Epoch 56: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.3545 - accuracy: 0.9356 - val_loss: 1.3340 - val_accuracy: 0.7879
# Epoch 57/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.9432
# Epoch 57: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 143ms/step - loss: 0.2646 - accuracy: 0.9432 - val_loss: 2.9723 - val_accuracy: 0.7803
# Epoch 58/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9621
# Epoch 58: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 145ms/step - loss: 0.2175 - accuracy: 0.9621 - val_loss: 1.7783 - val_accuracy: 0.8561
# Epoch 59/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1904 - accuracy: 0.9697
# Epoch 59: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.1904 - accuracy: 0.9697 - val_loss: 2.2109 - val_accuracy: 0.8712
# Epoch 60/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1800 - accuracy: 0.9886
# Epoch 60: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.1800 - accuracy: 0.9886 - val_loss: 2.1479 - val_accuracy: 0.8712
# Epoch 61/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2078 - accuracy: 0.9735
# Epoch 61: val_accuracy did not improve from 0.94697
# 33/33 [==============================] - 5s 146ms/step - loss: 0.2078 - accuracy: 0.9735 - val_loss: 5.0872 - val_accuracy: 0.7652

# %%
# Plot training & validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Get true labels and predictions
test_labels = np.concatenate([y for x, y in test_dataset], axis=0)
predictions = np.argmax(model.predict(test_dataset), axis=-1)
# Out:
# 17/17 [==============================] - 1s 36ms/step

# %%
# Classification report
print("Classification Report:")
print(classification_report(test_labels, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92        66
#            1       0.91      0.92      0.92        66
#
#     accuracy                           0.92       132
#    macro avg       0.92      0.92      0.92       132
# weighted avg       0.92      0.92      0.92       132

# %%
# Confusion matrix
conf_matrix = confusion_matrix(test_labels, predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(2)], yticklabels=[str(i) for i in range(2)])

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
