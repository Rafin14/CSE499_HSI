# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tensorflow.keras import models, layers, regularizers

# %%
config = tf.compat.v1.ConfigProto(gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
physical_devices = tf.config.experimental.list_physical_devices('GPU')

print("Num GPUs Available: ", len(physical_devices))
# Out:
# WARNING:tensorflow:From C:\Users\rafin\AppData\Local\Temp\ipykernel_11384\717319033.py:7: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Num GPUs Available:  1

# %%
data_train = np.load('Datasets/train.npy', allow_pickle= True)
data_test = np.load('Datasets/test.npy', allow_pickle= True)

train_labels = np.load('Datasets/train_labels.npy', allow_pickle= True)
test_labels = np.load('Datasets/test_labels.npy', allow_pickle= True)

data_train.shape, train_labels.shape, data_test.shape, test_labels.shape
# Out:
# ((264, 32, 32, 320), (264,), (132, 32, 32, 320), (132,))

# %%
mean = data_train.mean(axis=(0, 1, 2), keepdims=True)
std_dev = data_train.std(axis=(0, 1, 2), keepdims=True)

# Z-score normalization
data_train = (data_train - mean) / std_dev

data_test = (data_test - mean) / std_dev

print("Train Shape:", data_train.shape)
print("Test Shape:", data_test.shape)
# Out:
# Train Shape: (264, 32, 32, 320)
# Test Shape: (132, 32, 32, 320)

# %%
# Simulated HSI data
hsi_image_train = data_train
hsi_image_test = data_test

# Reshape to (264 * 1024, 320)
hsi_reshaped_train = hsi_image_train.reshape(-1, 320)
hsi_reshaped_test = hsi_image_test.reshape(-1, 320)

hsi_reshaped_train.shape, hsi_reshaped_test.shape
# Out:
# ((270336, 320), (135168, 320))

# %%
# Apply PCA
pca = PCA()
hsi_train_pca = pca.fit_transform(hsi_reshaped_train)

explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance)

# %%
plt.figure(figsize=(5, 5))
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--')
plt.xlabel('Number of Dimensions')
plt.ylabel('Total Variance Retained')
plt.title('Variance Retained vs No. of Dimensions')
plt.grid()
plt.show()

# %%
#No. of Dimensions that retains 95% varinace:
optimal_components = np.argmax(cumulative_explained_variance >= 0.99) + 1 
print(f"Number of Dimensions to retain 99% variance: {optimal_components}")

pca = PCA(n_components=optimal_components)

X_train_PCA = pca.fit_transform(hsi_reshaped_train)
X_test_pca = pca.transform(hsi_reshaped_test)

X_train_PCA.shape, X_test_pca.shape
# Out:
# Number of Dimensions to retain 99% variance: 199
# ((270336, 199), (135168, 199))

# %%
# Reshape back to the spatial dimensions
data_train = X_train_PCA.reshape(264, 32, 32, optimal_components)
data_test = X_test_pca.reshape(132, 32, 32, optimal_components)

data_train.shape, data_test.shape
# Out:
# ((264, 32, 32, 199), (132, 32, 32, 199))

# %%
# Add channel dimension to data
data_train = data_train[..., np.newaxis]
data_test = data_test[..., np.newaxis]

data_train.shape, data_test.shape
# Out:
# ((264, 32, 32, 199, 1), (132, 32, 32, 199, 1))

# %%
le= LabelEncoder()
y_train = le.fit_transform(train_labels)

le2= LabelEncoder()
y_test= le2.fit_transform(test_labels)

# %%
def augment_data(sample, label):
    
    # Random flip along different axes
    sample = tf.image.random_flip_left_right(sample)
    sample = tf.image.random_flip_up_down(sample)

    # Random rotation
    sample = tf.image.rot90(sample, k=np.random.randint(1, 4))  # k=1 to 3 random rotations of 90°

    # Random intensity scaling (brightness variation)
    sample = sample * tf.random.uniform([], 0.9, 1.1)  # Random scale between 0.9 and 1.1
    
    return sample, label

# %%
# Convert data to TensorFlow dataset

train_dataset = tf.data.Dataset.from_tensor_slices((data_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((data_test, y_test))

# Apply augmentation only on training data
train_dataset = train_dataset.map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle, batch, and prefetch
batch_size = 8

train_dataset = train_dataset.shuffle(buffer_size=100).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
'''
tf.random.set_seed(1234)

# Define the model architecture as in the previous answer
input_shape = (32, 32, 199, 1)

model = models.Sequential([
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu', input_shape=input_shape),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Flatten(),
    
    layers.Dense(128, activation='relu'),
    layers.Dense(2, activation='sigmoid')
])

model.summary()
'''

tf.random.set_seed(1234)

input_shape = (32, 32, 199, 1)

model = models.Sequential([
    
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.01), input_shape=input_shape),
    
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3

    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.001)),
    
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.0001)),
    
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3

    layers.Flatten(),

    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),  # Dropout with a rate of 0.5
    layers.Dense(64, activation='relu'),
    layers.Dense(2, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 30, 197, 32)   896
#
#  average_pooling3d (AverageP  (None, 15, 15, 98, 32)   0
#  ooling3D)
#
#  conv3d_1 (Conv3D)           (None, 13, 13, 96, 64)    55360
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 94, 128)   221312
#
#  average_pooling3d_1 (Averag  (None, 5, 5, 47, 128)    0
#  ePooling3D)
#
#  flatten (Flatten)           (None, 150400)            0
#
#  dense (Dense)               (None, 128)               19251328
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 19,537,282
# Trainable params: 19,537,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

'''
history = model.fit(train_dataset, epochs=100, validation_data=test_dataset, callbacks=[
                        tf.keras.callbacks.EarlyStopping(
                            monitor = 'loss',
                            patience = 5,
                            restore_best_weights = True
                        )
                    ])

'''
# Define the callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = 'best_model_2.h5',            # Path to save the best model
    monitor = 'accuracy',                   # Metric to monitor
    save_best_only = True,                 # Save only the best model
    save_weights_only = False,             # Save the entire model (architecture + weights)
    mode = 'max',                          # Mode 'max' because we want to maximize accuracy
    verbose = 1
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'loss',
    patience = 15,
    restore_best_weights = True
)

# Train the model with the callbacks
history = model.fit(
    train_dataset,
    epochs = 100,
    validation_data = test_dataset,
    callbacks = [checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 33/33 [==============================] - ETA: 0s - loss: 9.4525 - accuracy: 0.6818
# Epoch 1: accuracy improved from -inf to 0.68182, saving model to best_model_2.h5
# 33/33 [==============================] - 16s 163ms/step - loss: 9.4525 - accuracy: 0.6818 - val_loss: 1.0736 - val_accuracy: 0.5000
# Epoch 2/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0186 - accuracy: 0.3674
# Epoch 2: accuracy did not improve from 0.68182
# 33/33 [==============================] - 5s 144ms/step - loss: 1.0186 - accuracy: 0.3674 - val_loss: 0.9590 - val_accuracy: 0.6970
# Epoch 3/100
# 33/33 [==============================] - ETA: 0s - loss: 0.9781 - accuracy: 0.6970
# Epoch 3: accuracy improved from 0.68182 to 0.69697, saving model to best_model_2.h5
# 33/33 [==============================] - 5s 154ms/step - loss: 0.9781 - accuracy: 0.6970 - val_loss: 0.9224 - val_accuracy: 0.6439
# Epoch 4/100
# 33/33 [==============================] - ETA: 0s - loss: 0.9131 - accuracy: 0.5341
# Epoch 4: accuracy did not improve from 0.69697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.9131 - accuracy: 0.5341 - val_loss: 0.8193 - val_accuracy: 0.7500
# Epoch 5/100
# 33/33 [==============================] - ETA: 0s - loss: 0.8522 - accuracy: 0.6023
# Epoch 5: accuracy did not improve from 0.69697
# 33/33 [==============================] - 5s 144ms/step - loss: 0.8522 - accuracy: 0.6023 - val_loss: 0.7320 - val_accuracy: 0.8712
# Epoch 6/100
# 33/33 [==============================] - ETA: 0s - loss: 0.7328 - accuracy: 0.7311
# Epoch 6: accuracy improved from 0.69697 to 0.73106, saving model to best_model_2.h5
# 33/33 [==============================] - 5s 154ms/step - loss: 0.7328 - accuracy: 0.7311 - val_loss: 0.5259 - val_accuracy: 0.8864
# Epoch 7/100
# 33/33 [==============================] - ETA: 0s - loss: 0.7277 - accuracy: 0.7273
# Epoch 7: accuracy did not improve from 0.73106
# 33/33 [==============================] - 5s 145ms/step - loss: 0.7277 - accuracy: 0.7273 - val_loss: 0.4339 - val_accuracy: 0.8939
# Epoch 8/100
# 33/33 [==============================] - ETA: 0s - loss: 0.9199 - accuracy: 0.6894
# Epoch 8: accuracy did not improve from 0.73106
# 33/33 [==============================] - 5s 144ms/step - loss: 0.9199 - accuracy: 0.6894 - val_loss: 0.6734 - val_accuracy: 0.9091
# Epoch 9/100
# 33/33 [==============================] - ETA: 0s - loss: 0.7144 - accuracy: 0.8068
# Epoch 9: accuracy improved from 0.73106 to 0.80682, saving model to best_model_2.h5
# 33/33 [==============================] - 5s 155ms/step - loss: 0.7144 - accuracy: 0.8068 - val_loss: 0.5620 - val_accuracy: 0.9015
# Epoch 10/100
# 33/33 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.7652
# Epoch 10: accuracy did not improve from 0.80682
# 33/33 [==============================] - 5s 147ms/step - loss: 0.6937 - accuracy: 0.7652 - val_loss: 0.4864 - val_accuracy: 0.9470
# Epoch 11/100
# 33/33 [==============================] - ETA: 0s - loss: 0.5980 - accuracy: 0.8106
# Epoch 11: accuracy improved from 0.80682 to 0.81061, saving model to best_model_2.h5
# 33/33 [==============================] - 5s 154ms/step - loss: 0.5980 - accuracy: 0.8106 - val_loss: 0.4581 - val_accuracy: 0.9242
# Epoch 12/100
# 33/33 [==============================] - ETA: 0s - loss: 0.5787 - accuracy: 0.7803
# Epoch 12: accuracy did not improve from 0.81061
# 33/33 [==============================] - 5s 147ms/step - loss: 0.5787 - accuracy: 0.7803 - val_loss: 0.6512 - val_accuracy: 0.8182
# Epoch 13/100
# 33/33 [==============================] - ETA: 0s - loss: 0.5679 - accuracy: 0.8030
# Epoch 13: accuracy did not improve from 0.81061
# 33/33 [==============================] - 5s 146ms/step - loss: 0.5679 - accuracy: 0.8030 - val_loss: 0.8075 - val_accuracy: 0.9015
# Epoch 14/100
# 33/33 [==============================] - ETA: 0s - loss: 0.5786 - accuracy: 0.8258
# Epoch 14: accuracy improved from 0.81061 to 0.82576, saving model to best_model_2.h5
# 33/33 [==============================] - 5s 154ms/step - loss: 0.5786 - accuracy: 0.8258 - val_loss: 0.6736 - val_accuracy: 0.9167
# Epoch 15/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4627 - accuracy: 0.8712
# Epoch 15: accuracy improved from 0.82576 to 0.87121, saving model to best_model_2.h5
# 33/33 [==============================] - 5s 159ms/step - loss: 0.4627 - accuracy: 0.8712 - val_loss: 1.3490 - val_accuracy: 0.8258
# Epoch 16/100
# 33/33 [==============================] - ETA: 0s - loss: 0.5381 - accuracy: 0.8826
# Epoch 16: accuracy improved from 0.87121 to 0.88258, saving model to best_model_2.h5
# 33/33 [==============================] - 5s 156ms/step - loss: 0.5381 - accuracy: 0.8826 - val_loss: 0.5712 - val_accuracy: 0.9242
# Epoch 17/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4905 - accuracy: 0.8333
# Epoch 17: accuracy did not improve from 0.88258
# 33/33 [==============================] - 5s 144ms/step - loss: 0.4905 - accuracy: 0.8333 - val_loss: 0.7568 - val_accuracy: 0.9091
# Epoch 18/100
# 33/33 [==============================] - ETA: 0s - loss: 0.5288 - accuracy: 0.8106
# Epoch 18: accuracy did not improve from 0.88258
# 33/33 [==============================] - 5s 144ms/step - loss: 0.5288 - accuracy: 0.8106 - val_loss: 1.4569 - val_accuracy: 0.8106
# Epoch 19/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4441 - accuracy: 0.8485
# Epoch 19: accuracy did not improve from 0.88258
# 33/33 [==============================] - 5s 148ms/step - loss: 0.4441 - accuracy: 0.8485 - val_loss: 1.0257 - val_accuracy: 0.9167
# Epoch 20/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4202 - accuracy: 0.8826
# Epoch 20: accuracy did not improve from 0.88258
# 33/33 [==============================] - 5s 153ms/step - loss: 0.4202 - accuracy: 0.8826 - val_loss: 0.9039 - val_accuracy: 0.9167
# Epoch 21/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3792 - accuracy: 0.8902
# Epoch 21: accuracy improved from 0.88258 to 0.89015, saving model to best_model_2.h5
# 33/33 [==============================] - 6s 163ms/step - loss: 0.3792 - accuracy: 0.8902 - val_loss: 1.5303 - val_accuracy: 0.8864
# Epoch 22/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4330 - accuracy: 0.9015
# Epoch 22: accuracy improved from 0.89015 to 0.90152, saving model to best_model_2.h5
# 33/33 [==============================] - 5s 160ms/step - loss: 0.4330 - accuracy: 0.9015 - val_loss: 0.7232 - val_accuracy: 0.9167
# Epoch 23/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4053 - accuracy: 0.8864
# Epoch 23: accuracy did not improve from 0.90152
# 33/33 [==============================] - 5s 151ms/step - loss: 0.4053 - accuracy: 0.8864 - val_loss: 0.8505 - val_accuracy: 0.9091
# Epoch 24/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4821 - accuracy: 0.8295
# Epoch 24: accuracy did not improve from 0.90152
# 33/33 [==============================] - 5s 147ms/step - loss: 0.4821 - accuracy: 0.8295 - val_loss: 1.0275 - val_accuracy: 0.9015
# Epoch 25/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3640 - accuracy: 0.9091
# Epoch 25: accuracy improved from 0.90152 to 0.90909, saving model to best_model_2.h5
# 33/33 [==============================] - 5s 158ms/step - loss: 0.3640 - accuracy: 0.9091 - val_loss: 1.1993 - val_accuracy: 0.9091
# Epoch 26/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4373 - accuracy: 0.8902
# Epoch 26: accuracy did not improve from 0.90909
# 33/33 [==============================] - 5s 145ms/step - loss: 0.4373 - accuracy: 0.8902 - val_loss: 0.9607 - val_accuracy: 0.9167
# Epoch 27/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.8750
# Epoch 27: accuracy did not improve from 0.90909
# 33/33 [==============================] - 5s 147ms/step - loss: 0.3269 - accuracy: 0.8750 - val_loss: 1.4330 - val_accuracy: 0.9091
# Epoch 28/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2966 - accuracy: 0.9394
# Epoch 28: accuracy improved from 0.90909 to 0.93939, saving model to best_model_2.h5
# 33/33 [==============================] - 5s 156ms/step - loss: 0.2966 - accuracy: 0.9394 - val_loss: 1.4425 - val_accuracy: 0.9091
# Epoch 29/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3254 - accuracy: 0.9242
# Epoch 29: accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 149ms/step - loss: 0.3254 - accuracy: 0.9242 - val_loss: 1.5437 - val_accuracy: 0.9167
# Epoch 30/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3047 - accuracy: 0.9356
# Epoch 30: accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 149ms/step - loss: 0.3047 - accuracy: 0.9356 - val_loss: 1.1810 - val_accuracy: 0.9242
# Epoch 31/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2589 - accuracy: 0.9356
# Epoch 31: accuracy did not improve from 0.93939
# 33/33 [==============================] - 5s 153ms/step - loss: 0.2589 - accuracy: 0.9356 - val_loss: 1.6565 - val_accuracy: 0.9242
# Epoch 32/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2122 - accuracy: 0.9508
# Epoch 32: accuracy improved from 0.93939 to 0.95076, saving model to best_model_2.h5
# 33/33 [==============================] - 5s 162ms/step - loss: 0.2122 - accuracy: 0.9508 - val_loss: 2.5527 - val_accuracy: 0.8939
# Epoch 33/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3025 - accuracy: 0.9432
# Epoch 33: accuracy did not improve from 0.95076
# 33/33 [==============================] - 5s 153ms/step - loss: 0.3025 - accuracy: 0.9432 - val_loss: 0.9941 - val_accuracy: 0.8939
# Epoch 34/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3726 - accuracy: 0.8902
# Epoch 34: accuracy did not improve from 0.95076
# 33/33 [==============================] - 5s 150ms/step - loss: 0.3726 - accuracy: 0.8902 - val_loss: 1.2574 - val_accuracy: 0.8864
# Epoch 35/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3316 - accuracy: 0.9053
# Epoch 35: accuracy did not improve from 0.95076
# 33/33 [==============================] - 5s 153ms/step - loss: 0.3316 - accuracy: 0.9053 - val_loss: 1.7179 - val_accuracy: 0.9091
# Epoch 36/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.9470
# Epoch 36: accuracy did not improve from 0.95076
# 33/33 [==============================] - 5s 151ms/step - loss: 0.2844 - accuracy: 0.9470 - val_loss: 1.6123 - val_accuracy: 0.9091
# Epoch 37/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2253 - accuracy: 0.9583
# Epoch 37: accuracy improved from 0.95076 to 0.95833, saving model to best_model_2.h5
# 33/33 [==============================] - 6s 166ms/step - loss: 0.2253 - accuracy: 0.9583 - val_loss: 1.8595 - val_accuracy: 0.9091
# Epoch 38/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.9356
# Epoch 38: accuracy did not improve from 0.95833
# 33/33 [==============================] - 5s 151ms/step - loss: 0.2614 - accuracy: 0.9356 - val_loss: 1.3858 - val_accuracy: 0.9015
# Epoch 39/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2239 - accuracy: 0.9470
# Epoch 39: accuracy did not improve from 0.95833
# 33/33 [==============================] - 5s 152ms/step - loss: 0.2239 - accuracy: 0.9470 - val_loss: 1.8892 - val_accuracy: 0.9091
# Epoch 40/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.9508
# Epoch 40: accuracy did not improve from 0.95833
# 33/33 [==============================] - 5s 150ms/step - loss: 0.2316 - accuracy: 0.9508 - val_loss: 2.8366 - val_accuracy: 0.9015
# Epoch 41/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.9318
# Epoch 41: accuracy did not improve from 0.95833
# 33/33 [==============================] - 5s 153ms/step - loss: 0.2844 - accuracy: 0.9318 - val_loss: 2.4201 - val_accuracy: 0.9015
# Epoch 42/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9697
# Epoch 42: accuracy improved from 0.95833 to 0.96970, saving model to best_model_2.h5
# 33/33 [==============================] - 6s 163ms/step - loss: 0.1983 - accuracy: 0.9697 - val_loss: 2.1124 - val_accuracy: 0.9091
# Epoch 43/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1938 - accuracy: 0.9659
# Epoch 43: accuracy did not improve from 0.96970
# 33/33 [==============================] - 5s 154ms/step - loss: 0.1938 - accuracy: 0.9659 - val_loss: 2.1578 - val_accuracy: 0.9015
# Epoch 44/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2483 - accuracy: 0.9621
# Epoch 44: accuracy did not improve from 0.96970
# 33/33 [==============================] - 5s 151ms/step - loss: 0.2483 - accuracy: 0.9621 - val_loss: 2.0322 - val_accuracy: 0.8939
# Epoch 45/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1850 - accuracy: 0.9773
# Epoch 45: accuracy improved from 0.96970 to 0.97727, saving model to best_model_2.h5
# 33/33 [==============================] - 6s 166ms/step - loss: 0.1850 - accuracy: 0.9773 - val_loss: 2.2804 - val_accuracy: 0.9015
# Epoch 46/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.9356
# Epoch 46: accuracy did not improve from 0.97727
# 33/33 [==============================] - 5s 152ms/step - loss: 0.2494 - accuracy: 0.9356 - val_loss: 2.1873 - val_accuracy: 0.8939
# Epoch 47/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2066 - accuracy: 0.9583
# Epoch 47: accuracy did not improve from 0.97727
# 33/33 [==============================] - 5s 153ms/step - loss: 0.2066 - accuracy: 0.9583 - val_loss: 1.5507 - val_accuracy: 0.8939
# Epoch 48/100
# 33/33 [==============================] - ETA: 0s - loss: 0.
100
# 33/33 [==============================] - ETA: 0s - loss: 0.1744 - accuracy: 0.9848
# Epoch 77: accuracy did not improve from 0.99242
# 33/33 [==============================] - 5s 151ms/step - loss: 0.1744 - accuracy: 0.9848 - val_loss: 3.0180 - val_accuracy: 0.9015
# Epoch 78/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9848
# Epoch 78: accuracy did not improve from 0.99242
# 33/33 [==============================] - 5s 150ms/step - loss: 0.1525 - accuracy: 0.9848 - val_loss: 2.9029 - val_accuracy: 0.8712
# Epoch 79/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9773
# Epoch 79: accuracy did not improve from 0.99242
# 33/33 [==============================] - 5s 150ms/step - loss: 0.1453 - accuracy: 0.9773 - val_loss: 2.4003 - val_accuracy: 0.9015
# Epoch 80/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9811
# Epoch 80: accuracy did not improve from 0.99242
# 33/33 [==============================] - 5s 151ms/step - loss: 0.1468 - accuracy: 0.9811 - val_loss: 2.1863 - val_accuracy: 0.8788
# Epoch 81/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9962
# Epoch 81: accuracy improved from 0.99242 to 0.99621, saving model to best_model_2.h5
# 33/33 [==============================] - 6s 164ms/step - loss: 0.1169 - accuracy: 0.9962 - val_loss: 2.7556 - val_accuracy: 0.9015
# Epoch 82/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9924
# Epoch 82: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 153ms/step - loss: 0.1356 - accuracy: 0.9924 - val_loss: 2.6462 - val_accuracy: 0.9091
# Epoch 83/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9848
# Epoch 83: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 150ms/step - loss: 0.1335 - accuracy: 0.9848 - val_loss: 3.1385 - val_accuracy: 0.9015
# Epoch 84/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9848
# Epoch 84: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 153ms/step - loss: 0.1483 - accuracy: 0.9848 - val_loss: 2.2497 - val_accuracy: 0.8788
# Epoch 85/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9848
# Epoch 85: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 150ms/step - loss: 0.1429 - accuracy: 0.9848 - val_loss: 2.4280 - val_accuracy: 0.8788
# Epoch 86/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9962
# Epoch 86: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 151ms/step - loss: 0.1135 - accuracy: 0.9962 - val_loss: 2.8741 - val_accuracy: 0.8939
# Epoch 87/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1051 - accuracy: 0.9962
# Epoch 87: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 151ms/step - loss: 0.1051 - accuracy: 0.9962 - val_loss: 3.2738 - val_accuracy: 0.9015
# Epoch 88/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1716 - accuracy: 0.9811
# Epoch 88: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 153ms/step - loss: 0.1716 - accuracy: 0.9811 - val_loss: 2.1356 - val_accuracy: 0.8939
# Epoch 89/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9848
# Epoch 89: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 152ms/step - loss: 0.1332 - accuracy: 0.9848 - val_loss: 2.4888 - val_accuracy: 0.9091
# Epoch 90/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1117 - accuracy: 0.9962
# Epoch 90: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 154ms/step - loss: 0.1117 - accuracy: 0.9962 - val_loss: 1.9433 - val_accuracy: 0.9167
# Epoch 91/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1203 - accuracy: 0.9924
# Epoch 91: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 150ms/step - loss: 0.1203 - accuracy: 0.9924 - val_loss: 2.7423 - val_accuracy: 0.9091
# Epoch 92/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9962
# Epoch 92: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 151ms/step - loss: 0.1153 - accuracy: 0.9962 - val_loss: 2.2002 - val_accuracy: 0.9091
# Epoch 93/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9924
# Epoch 93: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 150ms/step - loss: 0.1361 - accuracy: 0.9924 - val_loss: 2.7594 - val_accuracy: 0.8864
# Epoch 94/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9735
# Epoch 94: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 151ms/step - loss: 0.1298 - accuracy: 0.9735 - val_loss: 2.4264 - val_accuracy: 0.9167
# Epoch 95/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1588 - accuracy: 0.9735
# Epoch 95: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 151ms/step - loss: 0.1588 - accuracy: 0.9735 - val_loss: 3.4123 - val_accuracy: 0.9091
# Epoch 96/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1978 - accuracy: 0.9545
# Epoch 96: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 151ms/step - loss: 0.1978 - accuracy: 0.9545 - val_loss: 1.5027 - val_accuracy: 0.9015
# Epoch 97/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.9962
# Epoch 97: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 150ms/step - loss: 0.1261 - accuracy: 0.9962 - val_loss: 2.1275 - val_accuracy: 0.9167
# Epoch 98/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1437 - accuracy: 0.9811
# Epoch 98: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 151ms/step - loss: 0.1437 - accuracy: 0.9811 - val_loss: 2.3367 - val_accuracy: 0.9242
# Epoch 99/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 0.9811
# Epoch 99: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 151ms/step - loss: 0.1683 - accuracy: 0.9811 - val_loss: 2.1303 - val_accuracy: 0.9091
# Epoch 100/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9811
# Epoch 100: accuracy did not improve from 0.99621
# 33/33 [==============================] - 5s 151ms/step - loss: 0.1885 - accuracy: 0.9811 - val_loss: 1.7641 - val_accuracy: 0.8712

# %%
# Plot training & validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Get true labels and predictions
test_labels = np.concatenate([y for x, y in test_dataset], axis=0)
predictions = np.argmax(model.predict(test_dataset), axis=-1)
# Out:
# 17/17 [==============================] - 1s 37ms/step

# %%
# Classification report
print("Classification Report:")
print(classification_report(test_labels, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87        66
#            1       0.89      0.85      0.87        66
#
#     accuracy                           0.87       132
#    macro avg       0.87      0.87      0.87       132
# weighted avg       0.87      0.87      0.87       132

# %%
# Confusion matrix
conf_matrix = confusion_matrix(test_labels, predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(2)], yticklabels=[str(i) for i in range(2)])

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
