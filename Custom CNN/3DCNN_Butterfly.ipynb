# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tensorflow.keras import models, layers, regularizers

# %%
config = tf.compat.v1.ConfigProto(gpu_options =
                         tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8)
)

config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)

physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
# Out:
# WARNING:tensorflow:From C:\Users\rafin\AppData\Local\Temp\ipykernel_6784\717319033.py:7: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Num GPUs Available:  1

# %%
data = np.load('Butterfly.npy', allow_pickle= True)
#data_test = np.load('Datasets/Apple_labels.npy', allow_pickle= True)

labels = np.load('Butterfly_labels.npy', allow_pickle= True)
#test_labels = np.load('Datasets/test_labels.npy', allow_pickle= True)

data.shape, labels.shape
# Out:
# ((240, 192, 32, 32), (240,))

# %%
data = np.transpose(data, (0, 2, 3, 1))  # (height, width, depth, channels)

data.shape
# Out:
# (240, 32, 32, 192)

# %%
mean = data.mean(axis=(0, 1, 2), keepdims=True)
std_dev = data.std(axis=(0, 1, 2), keepdims=True)

# Z-score normalization
data = (data - mean) / std_dev

print("Dataset shape:", data.shape)
# Out:
# Dataset shape: (240, 32, 32, 192)

# %%
# Split data into training, validation, and testing sets
data_train, data_test, train_labels, test_labels = train_test_split(data, labels, test_size = 0.25, random_state = 42, stratify = labels)

data_train.shape, train_labels.shape, data_test.shape, test_labels.shape
# Out:
# ((180, 32, 32, 192), (180,), (60, 32, 32, 192), (60,))

# %%
# Simulated HSI data
hsi_image_train = data_train
hsi_image_test = data_test

# Reshape to (264 * 1024, 320)
hsi_reshaped_train = hsi_image_train.reshape(-1, 192)
hsi_reshaped_test = hsi_image_test.reshape(-1, 192)

hsi_reshaped_train.shape, hsi_reshaped_test.shape
# Out:
# ((184320, 192), (61440, 192))

# %%
# Apply PCA
pca = PCA()
hsi_train_pca = pca.fit_transform(hsi_reshaped_train)

explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance)

# %%
plt.figure(figsize=(5, 5))
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--')
plt.xlabel('Number of Dimensions')
plt.ylabel('Total Variance Retained')
plt.title('Variance Retained vs No. of Dimensions')
plt.grid()
plt.show()

# %%
#No. of Dimensions that retains 95% varinace:
optimal_components = np.argmax(cumulative_explained_variance >= 0.999) + 1 
print(f"Number of Dimensions to retain 99% variance: {optimal_components}")

pca = PCA(n_components=optimal_components)

X_train_PCA = pca.fit_transform(hsi_reshaped_train)
X_test_pca = pca.transform(hsi_reshaped_test)

X_train_PCA.shape, X_test_pca.shape
# Out:
# Number of Dimensions to retain 99% variance: 122
# ((184320, 122), (61440, 122))

# %%
# Reshape back to the spatial dimensions
data_train = X_train_PCA.reshape(180, 32, 32, optimal_components)
data_test = X_test_pca.reshape(60, 32, 32, optimal_components)

data_train.shape, data_test.shape
# Out:
# ((180, 32, 32, 122), (60, 32, 32, 122))

# %%
le= LabelEncoder()
y_train = le.fit_transform(train_labels)

le2= LabelEncoder()
y_test= le2.fit_transform(test_labels)

# %%
# Add channel dimension to data
data_train = data_train[..., np.newaxis]
data_test = data_test[..., np.newaxis]

data_train.shape, data_test.shape
# Out:
# ((180, 32, 32, 122, 1), (60, 32, 32, 122, 1))

# %%
def augment_data(sample, label):
    
    # Ensure both are the same type
    random_scale = tf.cast(tf.random.uniform([], 0.9, 1.1), dtype=sample.dtype)
    sample = sample * random_scale  # Random scale between 0.9 and 1.1
    
    return sample, label

# %%
# Convert data to TensorFlow dataset

train_dataset = tf.data.Dataset.from_tensor_slices((data_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((data_test, y_test))

# Apply augmentation only on training data
train_dataset = train_dataset.map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle, batch, and prefetch
batch_size = 8

train_dataset = train_dataset.shuffle(buffer_size=100).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
'''
tf.random.set_seed(1234)

# Define the model architecture as in the previous answer
input_shape = (32, 32, 199, 1)

model = models.Sequential([
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu', input_shape=input_shape),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Flatten(),
    
    layers.Dense(128, activation='relu'),
    layers.Dense(2, activation='sigmoid')
])

model.summary()
'''

tf.random.set_seed(1234)

input_shape = (32, 32, optimal_components, 1)

model = models.Sequential([
    
    
    #1st Conv Layer
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.01), input_shape=input_shape),
    #layers.BatchNormalization(),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3
     
     
     
    #2nd Conv Layer
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.001)),
    #layers.BatchNormalization(),
    
    
    
    #3rd Conv Layer
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.0001)),
    #layers.BatchNormalization(),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3


    layers.Flatten(),
    
    
    #1st FC layer
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),  # Dropout with a rate of 0.5
    #layers.BatchNormalization(),
    
    
    
    #2nd FC layer
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
    layers.Dense(4, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 30, 120, 32)   896
#
#  average_pooling3d (AverageP  (None, 15, 15, 60, 32)   0
#  ooling3D)
#
#  conv3d_1 (Conv3D)           (None, 13, 13, 58, 64)    55360
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 56, 128)   221312
#
#  average_pooling3d_1 (Averag  (None, 5, 5, 28, 128)    0
#  ePooling3D)
#
#  flatten (Flatten)           (None, 89600)             0
#
#  dense (Dense)               (None, 128)               11468928
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 11,755,012
# Trainable params: 11,755,012
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

'''
history = model.fit(train_dataset, epochs=100, validation_data=test_dataset, callbacks=[
                        tf.keras.callbacks.EarlyStopping(
                            monitor = 'loss',
                            patience = 5,
                            restore_best_weights = True
                        )
                    ])

'''
# Define the callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = 'best_model_butterfly2.h5',            # Path to save the best model
    monitor = 'accuracy',                   # Metric to monitor
    save_best_only = True,                 # Save only the best model
    save_weights_only = False,             # Save the entire model (architecture + weights)
    mode = 'max',                          # Mode 'max' because we want to maximize accuracy
    verbose = 1
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'loss',
    patience = 15,
    restore_best_weights = True
)

# Train the model with the callbacks
history = model.fit(
    train_dataset,
    epochs = 100,
    validation_data = test_dataset,
    callbacks = [checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 23/23 [==============================] - ETA: 0s - loss: 1.6676 - accuracy: 0.2111
# Epoch 1: accuracy improved from -inf to 0.21111, saving model to best_model_butterfly2.h5
# 23/23 [==============================] - 10s 155ms/step - loss: 1.6676 - accuracy: 0.2111 - val_loss: 1.5719 - val_accuracy: 0.2500
# Epoch 2/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.5205 - accuracy: 0.3750
# Epoch 2: accuracy improved from 0.21111 to 0.37222, saving model to best_model_butterfly2.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 1.5190 - accuracy: 0.3722 - val_loss: 1.3974 - val_accuracy: 0.3167
# Epoch 3/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.2978 - accuracy: 0.4830
# Epoch 3: accuracy improved from 0.37222 to 0.48333, saving model to best_model_butterfly2.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 1.2897 - accuracy: 0.4833 - val_loss: 1.1493 - val_accuracy: 0.4333
# Epoch 4/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.0833 - accuracy: 0.5682
# Epoch 4: accuracy improved from 0.48333 to 0.56667, saving model to best_model_butterfly2.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 1.0863 - accuracy: 0.5667 - val_loss: 1.1622 - val_accuracy: 0.4667
# Epoch 5/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.0836 - accuracy: 0.5739
# Epoch 5: accuracy did not improve from 0.56667
# 23/23 [==============================] - 2s 76ms/step - loss: 1.0853 - accuracy: 0.5667 - val_loss: 1.0262 - val_accuracy: 0.5167
# Epoch 6/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.9609 - accuracy: 0.6250
# Epoch 6: accuracy improved from 0.56667 to 0.62778, saving model to best_model_butterfly2.h5
# 23/23 [==============================] - 2s 85ms/step - loss: 0.9529 - accuracy: 0.6278 - val_loss: 0.9402 - val_accuracy: 0.6667
# Epoch 7/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8251 - accuracy: 0.6648
# Epoch 7: accuracy improved from 0.62778 to 0.66667, saving model to best_model_butterfly2.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 0.8177 - accuracy: 0.6667 - val_loss: 0.8847 - val_accuracy: 0.6500
# Epoch 8/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8424 - accuracy: 0.6875
# Epoch 8: accuracy improved from 0.66667 to 0.67778, saving model to best_model_butterfly2.h5
# 23/23 [==============================] - 2s 83ms/step - loss: 0.8507 - accuracy: 0.6778 - val_loss: 0.9541 - val_accuracy: 0.5833
# Epoch 9/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8478 - accuracy: 0.6705
# Epoch 9: accuracy did not improve from 0.67778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.8455 - accuracy: 0.6722 - val_loss: 1.1664 - val_accuracy: 0.5000
# Epoch 10/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7945 - accuracy: 0.6989
# Epoch 10: accuracy improved from 0.67778 to 0.70000, saving model to best_model_butterfly2.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 0.7881 - accuracy: 0.7000 - val_loss: 1.0315 - val_accuracy: 0.5667
# Epoch 11/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7777 - accuracy: 0.6932
# Epoch 11: accuracy did not improve from 0.70000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7719 - accuracy: 0.7000 - val_loss: 0.9041 - val_accuracy: 0.5667
# Epoch 12/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7764 - accuracy: 0.6989
# Epoch 12: accuracy did not improve from 0.70000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7894 - accuracy: 0.6889 - val_loss: 0.8554 - val_accuracy: 0.6500
# Epoch 13/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7095 - accuracy: 0.7216
# Epoch 13: accuracy improved from 0.70000 to 0.72222, saving model to best_model_butterfly2.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 0.7063 - accuracy: 0.7222 - val_loss: 0.8292 - val_accuracy: 0.6333
# Epoch 14/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7146 - accuracy: 0.7216
# Epoch 14: accuracy did not improve from 0.72222
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7162 - accuracy: 0.7167 - val_loss: 0.8734 - val_accuracy: 0.6167
# Epoch 15/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.6909 - accuracy: 0.6932
# Epoch 15: accuracy did not improve from 0.72222
# 23/23 [==============================] - 2s 76ms/step - loss: 0.6864 - accuracy: 0.7000 - val_loss: 0.8422 - val_accuracy: 0.6000
# Epoch 16/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.6343 - accuracy: 0.7500
# Epoch 16: accuracy improved from 0.72222 to 0.74444, saving model to best_model_butterfly2.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 0.6371 - accuracy: 0.7444 - val_loss: 0.8775 - val_accuracy: 0.6000
# Epoch 17/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.6755 - accuracy: 0.7500
# Epoch 17: accuracy improved from 0.74444 to 0.75000, saving model to best_model_butterfly2.h5
# 23/23 [==============================] - 2s 83ms/step - loss: 0.6739 - accuracy: 0.7500 - val_loss: 0.8380 - val_accuracy: 0.6167
# Epoch 18/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.6811 - accuracy: 0.7216
# Epoch 18: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.6835 - accuracy: 0.7222 - val_loss: 0.8491 - val_accuracy: 0.6167
# Epoch 19/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.6783 - accuracy: 0.7386
# Epoch 19: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.6752 - accuracy: 0.7389 - val_loss: 0.7771 - val_accuracy: 0.6833
# Epoch 20/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7654 - accuracy: 0.7273
# Epoch 20: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7812 - accuracy: 0.7167 - val_loss: 0.8706 - val_accuracy: 0.6333
# Epoch 21/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.9105 - accuracy: 0.7102
# Epoch 21: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.9031 - accuracy: 0.7111 - val_loss: 1.0256 - val_accuracy: 0.5833
# Epoch 22/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7343 - accuracy: 0.7500
# Epoch 22: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7305 - accuracy: 0.7500 - val_loss: 0.9079 - val_accuracy: 0.6167
# Epoch 23/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7013 - accuracy: 0.7330
# Epoch 23: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.6967 - accuracy: 0.7333 - val_loss: 0.9291 - val_accuracy: 0.5833
# Epoch 24/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.6805 - accuracy: 0.7330
# Epoch 24: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 74ms/step - loss: 0.6780 - accuracy: 0.7333 - val_loss: 1.0070 - val_accuracy: 0.5833
# Epoch 25/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.6727 - accuracy: 0.7500
# Epoch 25: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 74ms/step - loss: 0.6774 - accuracy: 0.7444 - val_loss: 0.8836 - val_accuracy: 0.5667
# Epoch 26/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7814 - accuracy: 0.7045
# Epoch 26: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7885 - accuracy: 0.7000 - val_loss: 1.2298 - val_accuracy: 0.6000
# Epoch 27/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.9170 - accuracy: 0.6818
# Epoch 27: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.9219 - accuracy: 0.6778 - val_loss: 1.3279 - val_accuracy: 0.5333
# Epoch 28/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.9491 - accuracy: 0.6875
# Epoch 28: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.9643 - accuracy: 0.6778 - val_loss: 0.9964 - val_accuracy: 0.5833
# Epoch 29/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.9044 - accuracy: 0.6761
# Epoch 29: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.9233 - accuracy: 0.6722 - val_loss: 1.1968 - val_accuracy: 0.5667
# Epoch 30/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8406 - accuracy: 0.6989
# Epoch 30: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 75ms/step - loss: 0.8429 - accuracy: 0.7000 - val_loss: 0.9698 - val_accuracy: 0.5833
# Epoch 31/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7861 - accuracy: 0.7330
# Epoch 31: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 76ms/step - loss: 0.7944 - accuracy: 0.7278 - val_loss: 1.1511 - val_accuracy: 0.5500

# %%
# Plot training & validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Get true labels and predictions
test_labels = np.concatenate([y for x, y in test_dataset], axis=0)
predictions = np.argmax(model.predict(test_dataset), axis=-1)
# Out:
# 8/8 [==============================] - 0s 21ms/step

# %%
# Classification report
print("Classification Report:")
print(classification_report(test_labels, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.40      0.55        15
#            1       0.60      0.60      0.60        15
#            2       0.45      0.93      0.61        15
#            3       1.00      0.47      0.64        15
#
#     accuracy                           0.60        60
#    macro avg       0.73      0.60      0.60        60
# weighted avg       0.73      0.60      0.60        60

# %%
# Confusion matrix
conf_matrix = confusion_matrix(test_labels, predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(4)], yticklabels=[str(i) for i in range(4)])

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
