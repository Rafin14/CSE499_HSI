# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tensorflow.keras import models, layers, regularizers

# %%
config = tf.compat.v1.ConfigProto(gpu_options =
                         tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8)
)

config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)

physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
# Out:
# WARNING:tensorflow:From C:\Users\rafin\AppData\Local\Temp\ipykernel_12992\717319033.py:7: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Num GPUs Available:  1

# %%
data = np.load('Butterfly.npy', allow_pickle= True)
#data_test = np.load('Datasets/Apple_labels.npy', allow_pickle= True)

labels = np.load('Butterfly_labels.npy', allow_pickle= True)
#test_labels = np.load('Datasets/test_labels.npy', allow_pickle= True)

data.shape, labels.shape
# Out:
# ((240, 192, 32, 32), (240,))

# %%
data = np.transpose(data, (0, 2, 3, 1))  # (height, width, depth, channels)

data.shape
# Out:
# (240, 32, 32, 192)

# %%
mean = data.mean(axis=(0, 1, 2), keepdims=True)
std_dev = data.std(axis=(0, 1, 2), keepdims=True)

# Z-score normalization
data = (data - mean) / std_dev

print("Dataset shape:", data.shape)
# Out:
# Dataset shape: (240, 32, 32, 192)

# %%
# Split data into training, validation, and testing sets
data_train, data_test, train_labels, test_labels = train_test_split(data, labels, test_size = 0.25, random_state = 42, stratify = labels)

data_train.shape, train_labels.shape, data_test.shape, test_labels.shape
# Out:
# ((180, 32, 32, 192), (180,), (60, 32, 32, 192), (60,))

# %%
# Simulated HSI data
hsi_image_train = data_train
hsi_image_test = data_test

# Reshape to (264 * 1024, 320)
hsi_reshaped_train = hsi_image_train.reshape(-1, 192)
hsi_reshaped_test = hsi_image_test.reshape(-1, 192)

hsi_reshaped_train.shape, hsi_reshaped_test.shape
# Out:
# ((184320, 192), (61440, 192))

# %%
# Apply PCA
pca = PCA()
hsi_train_pca = pca.fit_transform(hsi_reshaped_train)

explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance)

# %%
plt.figure(figsize=(5, 5))
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--')
plt.xlabel('Number of Dimensions')
plt.ylabel('Total Variance Retained')
plt.title('Variance Retained vs No. of Dimensions')
plt.grid()
plt.show()

# %%
#No. of Dimensions that retains 95% varinace:
optimal_components = np.argmax(cumulative_explained_variance >= 0.999) + 1 
print(f"Number of Dimensions to retain 99% variance: {optimal_components}")

pca = PCA(n_components=optimal_components)

X_train_PCA = pca.fit_transform(hsi_reshaped_train)
X_test_pca = pca.transform(hsi_reshaped_test)

X_train_PCA.shape, X_test_pca.shape
# Out:
# Number of Dimensions to retain 99% variance: 122
# ((184320, 122), (61440, 122))

# %%
# Reshape back to the spatial dimensions
data_train = X_train_PCA.reshape(180, 32, 32, optimal_components)
data_test = X_test_pca.reshape(60, 32, 32, optimal_components)

data_train.shape, data_test.shape
# Out:
# ((180, 32, 32, 122), (60, 32, 32, 122))

# %%
le= LabelEncoder()
y_train = le.fit_transform(train_labels)

le2= LabelEncoder()
y_test= le2.fit_transform(test_labels)

# %%
# Add channel dimension to data
data_train = data_train[..., np.newaxis]
data_test = data_test[..., np.newaxis]

data_train.shape, data_test.shape
# Out:
# ((180, 32, 32, 122, 1), (60, 32, 32, 122, 1))

# %%
def augment_data(sample, label):
    
    # Ensure both are the same type
    random_scale = tf.cast(tf.random.uniform([], 0.9, 1.1), dtype=sample.dtype)
    sample = sample * random_scale  # Random scale between 0.9 and 1.1
    return sample, label

# %%
# Convert data to TensorFlow dataset

train_dataset = tf.data.Dataset.from_tensor_slices((data_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((data_test, y_test))

# Apply augmentation only on training data
train_dataset = train_dataset.map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle, batch, and prefetch
batch_size = 8

train_dataset = train_dataset.shuffle(buffer_size=100).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
'''
tf.random.set_seed(1234)

# Define the model architecture as in the previous answer
input_shape = (32, 32, 199, 1)

model = models.Sequential([
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu', input_shape=input_shape),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Flatten(),
    
    layers.Dense(128, activation='relu'),
    layers.Dense(2, activation='sigmoid')
])

model.summary()
'''

tf.random.set_seed(1234)

input_shape = (32, 32, optimal_components, 1)

model = models.Sequential([
    
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.01), input_shape=input_shape),
    
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3

    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.001)),
    
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.0001)),
    
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3

    layers.Flatten(),

    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),  # Dropout with a rate of 0.5
    layers.Dense(64, activation='relu'),
    layers.Dense(5, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 30, 120, 32)   896
#
#  average_pooling3d (AverageP  (None, 15, 15, 60, 32)   0
#  ooling3D)
#
#  conv3d_1 (Conv3D)           (None, 13, 13, 58, 64)    55360
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 56, 128)   221312
#
#  average_pooling3d_1 (Averag  (None, 5, 5, 28, 128)    0
#  ePooling3D)
#
#  flatten (Flatten)           (None, 89600)             0
#
#  dense (Dense)               (None, 128)               11468928
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 11,755,077
# Trainable params: 11,755,077
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

'''
history = model.fit(train_dataset, epochs=100, validation_data=test_dataset, callbacks=[
                        tf.keras.callbacks.EarlyStopping(
                            monitor = 'loss',
                            patience = 5,
                            restore_best_weights = True
                        )
                    ])

'''
# Define the callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = 'best_model_butterfly.h5',            # Path to save the best model
    monitor = 'accuracy',                   # Metric to monitor
    save_best_only = True,                 # Save only the best model
    save_weights_only = False,             # Save the entire model (architecture + weights)
    mode = 'max',                          # Mode 'max' because we want to maximize accuracy
    verbose = 1
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'loss',
    patience = 15,
    restore_best_weights = True
)

# Train the model with the callbacks
history = model.fit(
    train_dataset,
    epochs = 100,
    validation_data = test_dataset,
    callbacks = [checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 23/23 [==============================] - ETA: 0s - loss: 1.7826 - accuracy: 0.2000
# Epoch 1: accuracy improved from -inf to 0.20000, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 12s 157ms/step - loss: 1.7826 - accuracy: 0.2000 - val_loss: 1.6679 - val_accuracy: 0.2500
# Epoch 2/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.6226 - accuracy: 0.2670
# Epoch 2: accuracy improved from 0.20000 to 0.26667, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 1.6212 - accuracy: 0.2667 - val_loss: 1.5153 - val_accuracy: 0.2500
# Epoch 3/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.4839 - accuracy: 0.3466
# Epoch 3: accuracy improved from 0.26667 to 0.35556, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 1.4760 - accuracy: 0.3556 - val_loss: 1.3979 - val_accuracy: 0.4500
# Epoch 4/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.3243 - accuracy: 0.4716
# Epoch 4: accuracy improved from 0.35556 to 0.47778, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 1.3174 - accuracy: 0.4778 - val_loss: 1.3957 - val_accuracy: 0.3833
# Epoch 5/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.3584 - accuracy: 0.4943
# Epoch 5: accuracy improved from 0.47778 to 0.48889, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 83ms/step - loss: 1.3633 - accuracy: 0.4889 - val_loss: 1.4396 - val_accuracy: 0.4333
# Epoch 6/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.1813 - accuracy: 0.5625
# Epoch 6: accuracy improved from 0.48889 to 0.56111, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 1.1843 - accuracy: 0.5611 - val_loss: 1.2814 - val_accuracy: 0.3833
# Epoch 7/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.1735 - accuracy: 0.5568
# Epoch 7: accuracy did not improve from 0.56111
# 23/23 [==============================] - 2s 75ms/step - loss: 1.1707 - accuracy: 0.5556 - val_loss: 1.3173 - val_accuracy: 0.4333
# Epoch 8/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.0000 - accuracy: 0.6080
# Epoch 8: accuracy improved from 0.56111 to 0.61111, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 0.9894 - accuracy: 0.6111 - val_loss: 1.1879 - val_accuracy: 0.5167
# Epoch 9/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.0011 - accuracy: 0.6136
# Epoch 9: accuracy improved from 0.61111 to 0.61667, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 83ms/step - loss: 0.9958 - accuracy: 0.6167 - val_loss: 1.3073 - val_accuracy: 0.5000
# Epoch 10/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.9164 - accuracy: 0.6534
# Epoch 10: accuracy improved from 0.61667 to 0.65000, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 0.9203 - accuracy: 0.6500 - val_loss: 1.2555 - val_accuracy: 0.4667
# Epoch 11/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7588 - accuracy: 0.7273
# Epoch 11: accuracy improved from 0.65000 to 0.71111, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 0.7855 - accuracy: 0.7111 - val_loss: 1.3290 - val_accuracy: 0.5333
# Epoch 12/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8603 - accuracy: 0.6591
# Epoch 12: accuracy did not improve from 0.71111
# 23/23 [==============================] - 2s 75ms/step - loss: 0.8513 - accuracy: 0.6611 - val_loss: 1.0889 - val_accuracy: 0.5167
# Epoch 13/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8059 - accuracy: 0.6761
# Epoch 13: accuracy did not improve from 0.71111
# 23/23 [==============================] - 2s 74ms/step - loss: 0.7998 - accuracy: 0.6778 - val_loss: 1.0403 - val_accuracy: 0.5500
# Epoch 14/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7835 - accuracy: 0.6761
# Epoch 14: accuracy did not improve from 0.71111
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7856 - accuracy: 0.6722 - val_loss: 1.0999 - val_accuracy: 0.5333
# Epoch 15/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7715 - accuracy: 0.6989
# Epoch 15: accuracy did not improve from 0.71111
# 23/23 [==============================] - 2s 76ms/step - loss: 0.7771 - accuracy: 0.6944 - val_loss: 1.1167 - val_accuracy: 0.5500
# Epoch 16/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7462 - accuracy: 0.6761
# Epoch 16: accuracy did not improve from 0.71111
# 23/23 [==============================] - 2s 76ms/step - loss: 0.7464 - accuracy: 0.6778 - val_loss: 1.2723 - val_accuracy: 0.5500
# Epoch 17/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.9249 - accuracy: 0.6477
# Epoch 17: accuracy did not improve from 0.71111
# 23/23 [==============================] - 2s 75ms/step - loss: 0.9185 - accuracy: 0.6500 - val_loss: 1.1925 - val_accuracy: 0.5667
# Epoch 18/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8991 - accuracy: 0.6761
# Epoch 18: accuracy did not improve from 0.71111
# 23/23 [==============================] - 2s 75ms/step - loss: 0.9028 - accuracy: 0.6778 - val_loss: 1.1470 - val_accuracy: 0.5333
# Epoch 19/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8588 - accuracy: 0.6932
# Epoch 19: accuracy did not improve from 0.71111
# 23/23 [==============================] - 2s 75ms/step - loss: 0.8547 - accuracy: 0.7000 - val_loss: 1.1569 - val_accuracy: 0.5833
# Epoch 20/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7578 - accuracy: 0.7159
# Epoch 20: accuracy did not improve from 0.71111
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7659 - accuracy: 0.7111 - val_loss: 1.3039 - val_accuracy: 0.5833
# Epoch 21/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8134 - accuracy: 0.6875
# Epoch 21: accuracy did not improve from 0.71111
# 23/23 [==============================] - 2s 75ms/step - loss: 0.8139 - accuracy: 0.6889 - val_loss: 1.1019 - val_accuracy: 0.6167
# Epoch 22/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7734 - accuracy: 0.7159
# Epoch 22: accuracy improved from 0.71111 to 0.72222, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 83ms/step - loss: 0.7611 - accuracy: 0.7222 - val_loss: 1.3407 - val_accuracy: 0.5833
# Epoch 23/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7860 - accuracy: 0.7045
# Epoch 23: accuracy did not improve from 0.72222
# 23/23 [==============================] - 2s 76ms/step - loss: 0.7862 - accuracy: 0.7056 - val_loss: 1.0251 - val_accuracy: 0.6000
# Epoch 24/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7460 - accuracy: 0.7330
# Epoch 24: accuracy improved from 0.72222 to 0.73333, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 0.7407 - accuracy: 0.7333 - val_loss: 1.1363 - val_accuracy: 0.5833
# Epoch 25/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7863 - accuracy: 0.6705
# Epoch 25: accuracy did not improve from 0.73333
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7817 - accuracy: 0.6722 - val_loss: 1.2882 - val_accuracy: 0.5500
# Epoch 26/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7187 - accuracy: 0.7102
# Epoch 26: accuracy did not improve from 0.73333
# 23/23 [==============================] - 2s 77ms/step - loss: 0.7210 - accuracy: 0.7111 - val_loss: 1.1692 - val_accuracy: 0.5833
# Epoch 27/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7594 - accuracy: 0.6761
# Epoch 27: accuracy did not improve from 0.73333
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7638 - accuracy: 0.6722 - val_loss: 0.9623 - val_accuracy: 0.5833
# Epoch 28/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7635 - accuracy: 0.7159
# Epoch 28: accuracy did not improve from 0.73333
# 23/23 [==============================] - 2s 74ms/step - loss: 0.7664 - accuracy: 0.7111 - val_loss: 1.1622 - val_accuracy: 0.5333
# Epoch 29/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.0640 - accuracy: 0.6250
# Epoch 29: accuracy did not improve from 0.73333
# 23/23 [==============================] - 2s 75ms/step - loss: 1.0606 - accuracy: 0.6222 - val_loss: 1.1150 - val_accuracy: 0.6000
# Epoch 30/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8659 - accuracy: 0.7159
# Epoch 30: accuracy did not improve from 0.73333
# 23/23 [==============================] - 2s 75ms/step - loss: 0.9310 - accuracy: 0.7056 - val_loss: 1.1706 - val_accuracy: 0.5500
# Epoch 31/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.0443 - accuracy: 0.6534
# Epoch 31: accuracy did not improve from 0.73333
# 23/23 [==============================] - 2s 74ms/step - loss: 1.0450 - accuracy: 0.6556 - val_loss: 1.0764 - val_accuracy: 0.5833
# Epoch 32/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8985 - accuracy: 0.6364
# Epoch 32: accuracy did not improve from 0.73333
# 23/23 [==============================] - 2s 74ms/step - loss: 0.9009 - accuracy: 0.6333 - val_loss: 1.0558 - val_accuracy: 0.5667
# Epoch 33/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8367 - accuracy: 0.7045
# Epoch 33: accuracy did not improve from 0.73333
# 23/23 [==============================] - 2s 75ms/step - loss: 0.8340 - accuracy: 0.7056 - val_loss: 1.1215 - val_accuracy: 0.5500
# Epoch 34/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7995 - accuracy: 0.7443
# Epoch 34: accuracy improved from 0.73333 to 0.74444, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 82ms/step - loss: 0.7948 - accuracy: 0.7444 - val_loss: 1.0849 - val_accuracy: 0.5833
# Epoch 35/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8272 - accuracy: 0.7330
# Epoch 35: accuracy did not improve from 0.74444
# 23/23 [==============================] - 2s 75ms/step - loss: 0.8137 - accuracy: 0.7389 - val_loss: 1.2161 - val_accuracy: 0.5500
# Epoch 36/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8064 - accuracy: 0.6932
# Epoch 36: accuracy did not improve from 0.74444
# 23/23 [==============================] - 2s 75ms/step - loss: 0.8097 - accuracy: 0.6944 - val_loss: 1.0452 - val_accuracy: 0.5833
# Epoch 37/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7545 - accuracy: 0.7500
# Epoch 37: accuracy improved from 0.74444 to 0.75000, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 82ms/step - loss: 0.7555 - accuracy: 0.7500 - val_loss: 1.0959 - val_accuracy: 0.5500
# Epoch 38/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7724 - accuracy: 0.7045
# Epoch 38: accuracy did not improve from 0.75000
# 23/23 [==============================] - 2s 74ms/step - loss: 0.7669 - accuracy: 0.7056 - val_loss: 1.1314 - val_accuracy: 0.5500
# Epoch 39/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7043 - accuracy: 0.7727
# Epoch 39: accuracy improved from 0.75000 to 0.77778, saving model to best_model_butterfly.h5
# 23/23 [==============================] - 2s 84ms/step - loss: 0.6927 - accuracy: 0.7778 - val_loss: 1.0115 - val_accuracy: 0.5333
# Epoch 40/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7760 - accuracy: 0.7330
# Epoch 40: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7768 - accuracy: 0.7333 - val_loss: 1.2678 - val_accuracy: 0.5333
# Epoch 41/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7626 - accuracy: 0.7216
# Epoch 41: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7655 - accuracy: 0.7167 - val_loss: 1.0126 - val_accuracy: 0.5667
# Epoch 42/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7273 - accuracy: 0.7557
# Epoch 42: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 74ms/step - loss: 0.7245 - accuracy: 0.7556 - val_loss: 1.0959 - val_accuracy: 0.5667
# Epoch 43/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7261 - accuracy: 0.7216
# Epoch 43: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7291 - accuracy: 0.7222 - val_loss: 1.0510 - val_accuracy: 0.5833
# Epoch 44/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7401 - accuracy: 0.7216
# Epoch 44: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7370 - accuracy: 0.7222 - val_loss: 1.1484 - val_accuracy: 0.5833
# Epoch 45/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7805 - accuracy: 0.7273
# Epoch 45: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 74ms/step - loss: 0.7696 - accuracy: 0.7333 - val_loss: 1.3087 - val_accuracy: 0.5500
# Epoch 46/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7995 - accuracy: 0.7670
# Epoch 46: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7973 - accuracy: 0.7667 - val_loss: 1.3287 - val_accuracy: 0.5500
# Epoch 47/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7464 - accuracy: 0.7159
# Epoch 47: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7513 - accuracy: 0.7111 - val_loss: 1.2701 - val_accuracy: 0.5500
# Epoch 48/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.6589 - accuracy: 0.7443
# Epoch 48: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 76ms/step - loss: 0.6729 - accuracy: 0.7389 - val_loss: 1.2126 - val_accuracy: 0.5667
# Epoch 49/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.6831 - accuracy: 0.7330
# Epoch 49: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.6796 - accuracy: 0.7333 - val_loss: 1.2472 - val_accuracy: 0.5667
# Epoch 50/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7302 - accuracy: 0.7557
# Epoch 50: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7248 - accuracy: 0.7556 - val_loss: 1.1758 - val_accuracy: 0.5833
# Epoch 51/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7367 - accuracy: 0.7159
# Epoch 51: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7909 - accuracy: 0.7056 - val_loss: 1.3669 - val_accuracy: 0.5833
# Epoch 52/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.2028 - accuracy: 0.6648
# Epoch 52: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 1.1958 - accuracy: 0.6611 - val_loss: 1.5882 - val_accuracy: 0.5167
# Epoch 53/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.9965 - accuracy: 0.6818
# Epoch 53: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.9968 - accuracy: 0.6778 - val_loss: 1.2428 - val_accuracy: 0.4833
# Epoch 54/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8460 - accuracy: 0.7216
# Epoch 54: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.8517 - accuracy: 0.7167 - val_loss: 1.1357 - val_accuracy: 0.5500
# Epoch 55/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8056 - accuracy: 0.7102
# Epoch 55: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7927 - accuracy: 0.7167 - val_loss: 1.1618 - val_accuracy: 0.5167
# Epoch 56/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7906 - accuracy: 0.7386
# Epoch 56: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7899 - accuracy: 0.7389 - val_loss: 1.0980 - val_accuracy: 0.5667
# Epoch 57/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7374 - accuracy: 0.7500
# Epoch 57: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7384 - accuracy: 0.7500 - val_loss: 1.0987 - val_accuracy: 0.6000
# Epoch 58/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7322 - accuracy: 0.7500
# Epoch 58: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7315 - accuracy: 0.7500 - val_loss: 1.2552 - val_accuracy: 0.5667
# Epoch 59/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.9039 - accuracy: 0.7045
# Epoch 59: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.8977 - accuracy: 0.7111 - val_loss: 1.0071 - val_accuracy: 0.5667
# Epoch 60/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7500 - accuracy: 0.7443
# Epoch 60: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.7527 - accuracy: 0.7389 - val_loss: 1.1131 - val_accuracy: 0.5833
# Epoch 61/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.7292 - accuracy: 0.7557
# Epoch 61: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 76ms/step - loss: 0.7275 - accuracy: 0.7556 - val_loss: 1.0564 - val_accuracy: 0.5833
# Epoch 62/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.8301 - accuracy: 0.7443
# Epoch 62: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 75ms/step - loss: 0.8322 - accuracy: 0.7444 - val_loss: 1.0999 - val_accuracy: 0.5667
# Epoch 63/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.6866 - accuracy: 0.7784
# Epoch 63: accuracy did not improve from 0.77778
# 23/23 [==============================] - 2s 76ms/step - loss: 0.7086 - accuracy: 0.7611 - val_loss: 1.2710 - val_accuracy: 0.5667

# %%
# Plot training & validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Get true labels and predictions
test_labels = np.concatenate([y for x, y in test_dataset], axis=0)
predictions = np.argmax(model.predict(test_dataset), axis=-1)
# Out:
# 8/8 [==============================] - 0s 22ms/step

# %%
# Classification report
print("Classification Report:")
print(classification_report(test_labels, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.40      0.55        15
#            1       0.43      1.00      0.60        15
#            2       0.86      0.40      0.55        15
#            3       0.64      0.47      0.54        15
#
#     accuracy                           0.57        60
#    macro avg       0.69      0.57      0.56        60
# weighted avg       0.69      0.57      0.56        60

# %%
# Confusion matrix
conf_matrix = confusion_matrix(test_labels, predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(4)], yticklabels=[str(i) for i in range(4)])

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
