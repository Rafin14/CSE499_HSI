# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tensorflow.keras import models, layers, regularizers

# %%
config = tf.compat.v1.ConfigProto(gpu_options =
                         tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8)
)

config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)

physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
# Out:
# WARNING:tensorflow:From C:\Users\rafin\AppData\Local\Temp\ipykernel_12908\717319033.py:7: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Num GPUs Available:  1

# %%
data = np.load('Datasets/Apple_.npy', allow_pickle= True)
#data_test = np.load('Datasets/Apple_labels.npy', allow_pickle= True)

labels = np.load('Datasets/Apple_labels.npy', allow_pickle= True)
#test_labels = np.load('Datasets/test_labels.npy', allow_pickle= True)

data.shape, labels.shape
# Out:
# ((360, 300, 32, 32), (360,))

# %%
data = np.transpose(data, (0, 2, 3, 1))  # (height, width, depth, channels)

data.shape
# Out:
# (360, 32, 32, 300)

# %%
mean = data.mean(axis=(0, 1, 2), keepdims=True)
std_dev = data.std(axis=(0, 1, 2), keepdims=True)

# Z-score normalization
data = (data - mean) / std_dev

print("Dataset shape:", data.shape)
# Out:
# Dataset shape: (360, 32, 32, 300)

# %%
# Split data into training, validation, and testing sets
data_train, data_test, train_labels, test_labels = train_test_split(data, labels, test_size = 0.25, random_state = 42, stratify = labels)

data_train.shape, train_labels.shape, data_test.shape, test_labels.shape
# Out:
# ((270, 32, 32, 300), (270,), (90, 32, 32, 300), (90,))

# %%
# Simulated HSI data
hsi_image_train = data_train
hsi_image_test = data_test

# Reshape to (264 * 1024, 320)
hsi_reshaped_train = hsi_image_train.reshape(-1, 300)
hsi_reshaped_test = hsi_image_test.reshape(-1, 300)

hsi_reshaped_train.shape, hsi_reshaped_test.shape
# Out:
# ((276480, 300), (92160, 300))

# %%
# Apply PCA
pca = PCA()
hsi_train_pca = pca.fit_transform(hsi_reshaped_train)

explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance)

# %%
plt.figure(figsize=(5, 5))
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--')
plt.xlabel('Number of Dimensions')
plt.ylabel('Total Variance Retained')
plt.title('Variance Retained vs No. of Dimensions')
plt.grid()
plt.show()

# %%
#No. of Dimensions that retains 95% varinace:
optimal_components = np.argmax(cumulative_explained_variance >= 0.999) + 1 
print(f"Number of Dimensions to retain 99% variance: {optimal_components}")

pca = PCA(n_components=optimal_components)

X_train_PCA = pca.fit_transform(hsi_reshaped_train)
X_test_pca = pca.transform(hsi_reshaped_test)

X_train_PCA.shape, X_test_pca.shape
# Out:
# Number of Dimensions to retain 99% variance: 133
# ((276480, 133), (92160, 133))

# %%
# Reshape back to the spatial dimensions
data_train = X_train_PCA.reshape(270, 32, 32, optimal_components)
data_test = X_test_pca.reshape(90, 32, 32, optimal_components)

data_train.shape, data_test.shape
# Out:
# ((270, 32, 32, 133), (90, 32, 32, 133))

# %%
le= LabelEncoder()
y_train = le.fit_transform(train_labels)

le2= LabelEncoder()
y_test= le2.fit_transform(test_labels)

# %%
# Add channel dimension to data
data_train = data_train[..., np.newaxis]
data_test = data_test[..., np.newaxis]

data_train.shape, data_test.shape
# Out:
# ((270, 32, 32, 133, 1), (90, 32, 32, 133, 1))

# %%
def augment_data(sample, label):
    
    # Random flip along different axes
    sample = tf.image.random_flip_left_right(sample)
    sample = tf.image.random_flip_up_down(sample)

    # Random rotation
    sample = tf.image.rot90(sample, k=np.random.randint(1, 4))  # k=1 to 3 random rotations of 90°

    # Random intensity scaling (brightness variation)
    sample = sample * tf.random.uniform([], 0.9, 1.1)  # Random scale between 0.9 and 1.1
    
    return sample, label

# %%
# Convert data to TensorFlow dataset

train_dataset = tf.data.Dataset.from_tensor_slices((data_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((data_test, y_test))

# Apply augmentation only on training data
train_dataset = train_dataset.map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle, batch, and prefetch
batch_size = 8

train_dataset = train_dataset.shuffle(buffer_size=100).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
'''
tf.random.set_seed(1234)

# Define the model architecture as in the previous answer
input_shape = (32, 32, 199, 1)

model = models.Sequential([
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu', input_shape=input_shape),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Flatten(),
    
    layers.Dense(128, activation='relu'),
    layers.Dense(2, activation='sigmoid')
])

model.summary()
'''

tf.random.set_seed(1234)

input_shape = (32, 32, optimal_components, 1)

model = models.Sequential([
    
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.01), input_shape=input_shape),
    
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3

    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.001)),
    
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.0001)),
    
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3

    layers.Flatten(),

    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),  # Dropout with a rate of 0.5
    layers.Dense(64, activation='relu'),
    layers.Dense(5, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_3 (Conv3D)           (None, 30, 30, 131, 32)   896
#
#  average_pooling3d_2 (Averag  (None, 15, 15, 65, 32)   0
#  ePooling3D)
#
#  conv3d_4 (Conv3D)           (None, 13, 13, 63, 64)    55360
#
#  conv3d_5 (Conv3D)           (None, 11, 11, 61, 128)   221312
#
#  average_pooling3d_3 (Averag  (None, 5, 5, 30, 128)    0
#  ePooling3D)
#
#  flatten_1 (Flatten)         (None, 96000)             0
#
#  dense_3 (Dense)             (None, 128)               12288128
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 12,574,277
# Trainable params: 12,574,277
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

'''
history = model.fit(train_dataset, epochs=100, validation_data=test_dataset, callbacks=[
                        tf.keras.callbacks.EarlyStopping(
                            monitor = 'loss',
                            patience = 5,
                            restore_best_weights = True
                        )
                    ])

'''
# Define the callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = 'best_model_apple.h5',            # Path to save the best model
    monitor = 'accuracy',                   # Metric to monitor
    save_best_only = True,                 # Save only the best model
    save_weights_only = False,             # Save the entire model (architecture + weights)
    mode = 'max',                          # Mode 'max' because we want to maximize accuracy
    verbose = 1
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'loss',
    patience = 15,
    restore_best_weights = True
)

# Train the model with the callbacks
history = model.fit(
    train_dataset,
    epochs = 100,
    validation_data = test_dataset,
    callbacks = [checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 1.7980 - accuracy: 0.2926
# Epoch 1: accuracy improved from -inf to 0.29259, saving model to best_model_apple.h5
# 34/34 [==============================] - 14s 310ms/step - loss: 1.7980 - accuracy: 0.2926 - val_loss: 1.6940 - val_accuracy: 0.3333
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 1.6957 - accuracy: 0.3370
# Epoch 2: accuracy improved from 0.29259 to 0.33704, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 110ms/step - loss: 1.6957 - accuracy: 0.3370 - val_loss: 1.6455 - val_accuracy: 0.3333
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 1.6560 - accuracy: 0.3074
# Epoch 3: accuracy did not improve from 0.33704
# 34/34 [==============================] - 4s 104ms/step - loss: 1.6560 - accuracy: 0.3074 - val_loss: 1.6509 - val_accuracy: 0.3333
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 1.6450 - accuracy: 0.3333
# Epoch 4: accuracy did not improve from 0.33704
# 34/34 [==============================] - 4s 110ms/step - loss: 1.6450 - accuracy: 0.3333 - val_loss: 1.6262 - val_accuracy: 0.3333
# Epoch 5/100
# 34/34 [==============================] - ETA: 0s - loss: 1.6029 - accuracy: 0.3259
# Epoch 5: accuracy did not improve from 0.33704
# 34/34 [==============================] - 4s 103ms/step - loss: 1.6029 - accuracy: 0.3259 - val_loss: 1.6089 - val_accuracy: 0.3333
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 1.6033 - accuracy: 0.3259
# Epoch 6: accuracy did not improve from 0.33704
# 34/34 [==============================] - 4s 105ms/step - loss: 1.6033 - accuracy: 0.3259 - val_loss: 1.6117 - val_accuracy: 0.3333
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 1.5792 - accuracy: 0.3333
# Epoch 7: accuracy did not improve from 0.33704
# 34/34 [==============================] - 4s 109ms/step - loss: 1.5792 - accuracy: 0.3333 - val_loss: 1.5979 - val_accuracy: 0.3333
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 1.5655 - accuracy: 0.3333
# Epoch 8: accuracy did not improve from 0.33704
# 34/34 [==============================] - 4s 101ms/step - loss: 1.5655 - accuracy: 0.3333 - val_loss: 1.5967 - val_accuracy: 0.3333
# Epoch 9/100
# 34/34 [==============================] - ETA: 0s - loss: 1.5214 - accuracy: 0.3333
# Epoch 9: accuracy did not improve from 0.33704
# 34/34 [==============================] - 4s 103ms/step - loss: 1.5214 - accuracy: 0.3333 - val_loss: 1.6024 - val_accuracy: 0.3333
# Epoch 10/100
# 34/34 [==============================] - ETA: 0s - loss: 1.4962 - accuracy: 0.3407
# Epoch 10: accuracy improved from 0.33704 to 0.34074, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 113ms/step - loss: 1.4962 - accuracy: 0.3407 - val_loss: 1.6060 - val_accuracy: 0.3333
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 1.5521 - accuracy: 0.3296
# Epoch 11: accuracy did not improve from 0.34074
# 34/34 [==============================] - 4s 103ms/step - loss: 1.5521 - accuracy: 0.3296 - val_loss: 1.6141 - val_accuracy: 0.3333
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 1.5021 - accuracy: 0.3296
# Epoch 12: accuracy did not improve from 0.34074
# 34/34 [==============================] - 4s 107ms/step - loss: 1.5021 - accuracy: 0.3296 - val_loss: 1.6137 - val_accuracy: 0.3333
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 1.4643 - accuracy: 0.3444
# Epoch 13: accuracy improved from 0.34074 to 0.34444, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 114ms/step - loss: 1.4643 - accuracy: 0.3444 - val_loss: 1.6170 - val_accuracy: 0.3333
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 1.4199 - accuracy: 0.4074
# Epoch 14: accuracy improved from 0.34444 to 0.40741, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 112ms/step - loss: 1.4199 - accuracy: 0.4074 - val_loss: 1.6547 - val_accuracy: 0.3000
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 1.4269 - accuracy: 0.4037
# Epoch 15: accuracy did not improve from 0.40741
# 34/34 [==============================] - 4s 108ms/step - loss: 1.4269 - accuracy: 0.4037 - val_loss: 1.6743 - val_accuracy: 0.3000
# Epoch 16/100
# 34/34 [==============================] - ETA: 0s - loss: 1.3710 - accuracy: 0.4444
# Epoch 16: accuracy improved from 0.40741 to 0.44444, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 109ms/step - loss: 1.3710 - accuracy: 0.4444 - val_loss: 1.6757 - val_accuracy: 0.2778
# Epoch 17/100
# 34/34 [==============================] - ETA: 0s - loss: 1.3649 - accuracy: 0.4407
# Epoch 17: accuracy did not improve from 0.44444
# 34/34 [==============================] - 4s 106ms/step - loss: 1.3649 - accuracy: 0.4407 - val_loss: 1.6783 - val_accuracy: 0.3222
# Epoch 18/100
# 34/34 [==============================] - ETA: 0s - loss: 1.3371 - accuracy: 0.4481
# Epoch 18: accuracy improved from 0.44444 to 0.44815, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 114ms/step - loss: 1.3371 - accuracy: 0.4481 - val_loss: 1.6701 - val_accuracy: 0.2778
# Epoch 19/100
# 34/34 [==============================] - ETA: 0s - loss: 1.2626 - accuracy: 0.4370
# Epoch 19: accuracy did not improve from 0.44815
# 34/34 [==============================] - 4s 104ms/step - loss: 1.2626 - accuracy: 0.4370 - val_loss: 1.7053 - val_accuracy: 0.2667
# Epoch 20/100
# 34/34 [==============================] - ETA: 0s - loss: 1.2515 - accuracy: 0.4407
# Epoch 20: accuracy did not improve from 0.44815
# 34/34 [==============================] - 4s 107ms/step - loss: 1.2515 - accuracy: 0.4407 - val_loss: 1.6964 - val_accuracy: 0.2778
# Epoch 21/100
# 34/34 [==============================] - ETA: 0s - loss: 1.2236 - accuracy: 0.4630
# Epoch 21: accuracy improved from 0.44815 to 0.46296, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 113ms/step - loss: 1.2236 - accuracy: 0.4630 - val_loss: 1.7479 - val_accuracy: 0.2000
# Epoch 22/100
# 34/34 [==============================] - ETA: 0s - loss: 1.2089 - accuracy: 0.5037
# Epoch 22: accuracy improved from 0.46296 to 0.50370, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 113ms/step - loss: 1.2089 - accuracy: 0.5037 - val_loss: 1.7549 - val_accuracy: 0.1556
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 1.1889 - accuracy: 0.5111
# Epoch 23: accuracy improved from 0.50370 to 0.51111, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 118ms/step - loss: 1.1889 - accuracy: 0.5111 - val_loss: 1.7578 - val_accuracy: 0.2000
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 1.1174 - accuracy: 0.5296
# Epoch 24: accuracy improved from 0.51111 to 0.52963, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 112ms/step - loss: 1.1174 - accuracy: 0.5296 - val_loss: 1.7711 - val_accuracy: 0.2444
# Epoch 25/100
# 34/34 [==============================] - ETA: 0s - loss: 1.1615 - accuracy: 0.5593
# Epoch 25: accuracy improved from 0.52963 to 0.55926, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 124ms/step - loss: 1.1615 - accuracy: 0.5593 - val_loss: 1.7182 - val_accuracy: 0.3333
# Epoch 26/100
# 34/34 [==============================] - ETA: 0s - loss: 1.1363 - accuracy: 0.5704
# Epoch 26: accuracy improved from 0.55926 to 0.57037, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 108ms/step - loss: 1.1363 - accuracy: 0.5704 - val_loss: 1.7590 - val_accuracy: 0.2556
# Epoch 27/100
# 34/34 [==============================] - ETA: 0s - loss: 1.0785 - accuracy: 0.5778
# Epoch 27: accuracy improved from 0.57037 to 0.57778, saving model to best_model_apple.h5
# 34/34 [==============================] - 3s 99ms/step - loss: 1.0785 - accuracy: 0.5778 - val_loss: 1.7416 - val_accuracy: 0.1889
# Epoch 28/100
# 34/34 [==============================] - ETA: 0s - loss: 1.0716 - accuracy: 0.5852
# Epoch 28: accuracy improved from 0.57778 to 0.58519, saving model to best_model_apple.h5
# 34/34 [==============================] - 4s 111ms/step - loss: 1.0716 - accuracy: 0.5852 - val_loss: 1.7411 - val_accuracy: 0.2556
# Epoch 29/100
# 34/34 [==============================] - ETA: 0s - loss: 1.0546 - accuracy: 0.5815
# Epoch 29: accuracy did not improve from 0.58519
# 34/34 [==============================] - 3s 91ms/step - loss: 1.0546 - accuracy: 0.5815 - val_loss: 1.7972 - val_accuracy: 0.1778
# Epoch 30/100
# 34/34 [==============================] - ETA: 0s - loss: 1.0794 - accuracy: 0.5741
# Epoch 30: accuracy did not improve from 0.58519
# 34/34 [==============================] - 3s 90ms/step - loss: 1.0794 - accuracy: 0.5741 - val_loss: 1.7467 - val_accuracy: 0.2333
# Epoch 31/100
# 34/34 [==============================] - ETA: 0s - loss: 1.0523 - accuracy: 0.5741
# Epoch 31: accuracy did not improve from 0.58519
# 34/34 [==============================] - 3s 94ms/step - loss: 1.0523 - accuracy: 0.5741 - val_loss: 1.7766 - val_accuracy: 0.1333
# Epoch 32/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9547 - accuracy: 0.6593
# Epoch 32: accuracy improved from 0.58519 to 0.65926, saving model to best_model_apple.h5
# 34/34 [==============================] - 3s 99ms/step - loss: 0.9547 - accuracy: 0.6593 - val_loss: 1.7593 - val_accuracy: 0.2222
# Epoch 33/100
# 34/34 [==============================] - ETA: 0s - loss: 1.0293 - accuracy: 0.6037
# Epoch 33: accuracy did not improve from 0.65926
# 34/34 [==============================] - 3s 91ms/step - loss: 1.0293 - accuracy: 0.6037 - val_loss: 1.7810 - val_accuracy: 0.2000
# Epoch 34/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9617 - accuracy: 0.6037
# Epoch 34: accuracy did not improve from 0.65926
# 34/34 [==============================] - 3s 92ms/step - loss: 0.9617 - accuracy: 0.6037 - val_loss: 1.7700 - val_accuracy: 0.1556
# Epoch 35/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9742 - accuracy: 0.6259
# Epoch 35: accuracy did not improve from 0.65926
# 34/34 [==============================] - 3s 91ms/step - loss: 0.9742 - accuracy: 0.6259 - val_loss: 1.7529 - val_accuracy: 0.2111
# Epoch 36/100
# 34/34 [==============================] - ETA: 0s - loss: 1.0922 - accuracy: 0.5815
# Epoch 36: accuracy did not improve from 0.65926
# 34/34 [==============================] - 3s 91ms/step - loss: 1.0922 - accuracy: 0.5815 - val_loss: 1.8096 - val_accuracy: 0.1222
# Epoch 37/100
# 34/34 [==============================] - ETA: 0s - loss: 1.0353 - accuracy: 0.5889
# Epoch 37: accuracy did not improve from 0.65926
# 34/34 [==============================] - 3s 92ms/step - loss: 1.0353 - accuracy: 0.5889 - val_loss: 1.7551 - val_accuracy: 0.2000
# Epoch 38/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9886 - accuracy: 0.6074
# Epoch 38: accuracy did not improve from 0.65926
# 34/34 [==============================] - 3s 91ms/step - loss: 0.9886 - accuracy: 0.6074 - val_loss: 1.7631 - val_accuracy: 0.1556
# Epoch 39/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9459 - accuracy: 0.6481
# Epoch 39: accuracy did not improve from 0.65926
# 34/34 [==============================] - 3s 92ms/step - loss: 0.9459 - accuracy: 0.6481 - val_loss: 1.8120 - val_accuracy: 0.2222
# Epoch 40/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9608 - accuracy: 0.6000
# Epoch 40: accuracy did not improve from 0.65926
# 34/34 [==============================] - 3s 92ms/step - loss: 0.9608 - accuracy: 0.6000 - val_loss: 1.8104 - val_accuracy: 0.2000
# Epoch 41/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8980 - accuracy: 0.6667
# Epoch 41: accuracy improved from 0.65926 to 0.66667, saving model to best_model_apple.h5
# 34/34 [==============================] - 3s 98ms/step - loss: 0.8980 - accuracy: 0.6667 - val_loss: 1.8228 - val_accuracy: 0.2000
# Epoch 42/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9134 - accuracy: 0.6741
# Epoch 42: accuracy improved from 0.66667 to 0.67407, saving model to best_model_apple.h5
# 34/34 [==============================] - 3s 96ms/step - loss: 0.9134 - accuracy: 0.6741 - val_loss: 1.8445 - val_accuracy: 0.1667
# Epoch 43/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9542 - accuracy: 0.6593
# Epoch 43: accuracy did not improve from 0.67407
# 34/34 [==============================] - 3s 92ms/step - loss: 0.9542 - accuracy: 0.6593 - val_loss: 1.9395 - val_accuracy: 0.1556
# Epoch 44/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8760 - accuracy: 0.6704
# Epoch 44: accuracy did not improve from 0.67407
# 34/34 [==============================] - 3s 93ms/step - loss: 0.8760 - accuracy: 0.6704 - val_loss: 1.9105 - val_accuracy: 0.1667
# Epoch 45/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9074 - accuracy: 0.6481
# Epoch 45: accuracy did not improve from 0.67407
# 34/34 [==============================] - 3s 90ms/step - loss: 0.9074 - accuracy: 0.6481 - val_loss: 1.8602 - val_accuracy: 0.1889
# Epoch 46/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8546 - accuracy: 0.7037
# Epoch 46: accuracy improved from 0.67407 to 0.70370, saving model to best_model_apple.h5
# 34/34 [==============================] - 3s 99ms/step - loss: 0.8546 - accuracy: 0.7037 - val_loss: 1.9121 - val_accuracy: 0.1556
# Epoch 47/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9408 - accuracy: 0.6444
# Epoch 47: accuracy did not improve from 0.70370
# 34/34 [==============================] - 3s 92ms/step - loss: 0.9408 - accuracy: 0.6444 - val_loss: 1.8310 - val_accuracy: 0.1667
# Epoch 48/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8866 - accuracy: 0.6778
# Epoch 48: accuracy did not improve from 0.70370
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8866 - accuracy: 0.6778 - val_loss: 1.8438 - val_accuracy: 0.1222
# Epoch 49/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8881 - accuracy: 0.6926
# Epoch 49: accuracy did not improve from 0.70370
# 34/34 [==============================] - 3s 93ms/step - loss: 0.8881 - accuracy: 0.6926 - val_loss: 1.8614 - val_accuracy: 0.1778
# Epoch 50/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8494 - accuracy: 0.6852
# Epoch 50: accuracy did not improve from 0.70370
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8494 - accuracy: 0.6852 - val_loss: 1.8256 - val_accuracy: 0.1444
# Epoch 51/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8751 - accuracy: 0.7296
# Epoch 51: accuracy improved from 0.70370 to 0.72963, saving model to best_model_apple.h5
# 34/34 [==============================] - 3s 99ms/step - loss: 0.8751 - accuracy: 0.7296 - val_loss: 1.8002 - val_accuracy: 0.1889
# Epoch 52/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8489 - accuracy: 0.7000
# Epoch 52: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8489 - accuracy: 0.7000 - val_loss: 2.0157 - val_accuracy: 0.1444
# Epoch 53/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9089 - accuracy: 0.6630
# Epoch 53: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 92ms/step - loss: 0.9089 - accuracy: 0.6630 - val_loss: 1.7975 - val_accuracy: 0.2556
# Epoch 54/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9388 - accuracy: 0.6852
# Epoch 54: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 92ms/step - loss: 0.9388 - accuracy: 0.6852 - val_loss: 1.8755 - val_accuracy: 0.1667
# Epoch 55/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8220 - accuracy: 0.7000
# Epoch 55: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 94ms/step - loss: 0.8220 - accuracy: 0.7000 - val_loss: 1.9309 - val_accuracy: 0.1889
# Epoch 56/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8841 - accuracy: 0.7296
# Epoch 56: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8841 - accuracy: 0.7296 - val_loss: 2.0343 - val_accuracy: 0.1667
# Epoch 57/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8286 - accuracy: 0.6926
# Epoch 57: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 91ms/step - loss: 0.8286 - accuracy: 0.6926 - val_loss: 1.9684 - val_accuracy: 0.2333
# Epoch 58/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9025 - accuracy: 0.6370
# Epoch 58: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 92ms/step - loss: 0.9025 - accuracy: 0.6370 - val_loss: 1.9308 - val_accuracy: 0.1556
# Epoch 59/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8200 - accuracy: 0.7222
# Epoch 59: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 94ms/step - loss: 0.8200 - accuracy: 0.7222 - val_loss: 1.9311 - val_accuracy: 0.1667
# Epoch 60/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8270 - accuracy: 0.7074
# Epoch 60: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 93ms/step - loss: 0.8270 - accuracy: 0.7074 - val_loss: 1.8837 - val_accuracy: 0.2111
# Epoch 61/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8739 - accuracy: 0.6889
# Epoch 61: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8739 - accuracy: 0.6889 - val_loss: 2.0337 - val_accuracy: 0.1556
# Epoch 62/100
# 34/34 [==============================] - ETA: 0s - loss: 0.9391 - accuracy: 0.6593
# Epoch 62: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 91ms/step - loss: 0.9391 - accuracy: 0.6593 - val_loss: 1.9826 - val_accuracy: 0.1667
# Epoch 63/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8015 - accuracy: 0.7074
# Epoch 63: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 91ms/step - loss: 0.8015 - accuracy: 0.7074 - val_loss: 1.9742 - val_accuracy: 0.1778
# Epoch 64/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8097 - accuracy: 0.7037
# Epoch 64: accuracy did not improve from 0.72963
# 34/34 [==============================] - 3s 91ms/step - loss: 0.8097 - accuracy: 0.7037 - val_loss: 1.9533 - val_accuracy: 0.1556
# Epoch 65/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7658 - accuracy: 0.7407
# Epoch 65: accuracy improved from 0.72963 to 0.74074, saving model to best_model_apple.h5
# 34/34 [==============================] - 3s 99ms/step - loss: 0.7658 - accuracy: 0.7407 - val_loss: 1.8980 - val_accuracy: 0.1556
# Epoch 66/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8615 - accuracy: 0.6778
# Epoch 66: accuracy did not improve from 0.74074
# 34/34 [==============================] - 3s 91ms/step - loss: 0.8615 - accuracy: 0.6778 - val_loss: 1.9122 - val_accuracy: 0.1667
# Epoch 67/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8530 - accuracy: 0.6778
# Epoch 67: accuracy did not improve from 0.74074
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8530 - accuracy: 0.6778 - val_loss: 1.8893 - val_accuracy: 0.1778
# Epoch 68/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8950 - accuracy: 0.6889
# Epoch 68: accuracy did not improve from 0.74074
# 34/34 [==============================] - 3s 93ms/step - loss: 0.8950 - accuracy: 0.6889 - val_loss: 1.9194 - val_accuracy: 0.1778
# Epoch 69/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7622 - accuracy: 0.7370
# Epoch 69: accuracy did not improve from 0.74074
# 34/34 [==============================] - 3s 92ms/step - loss: 0.7622 - accuracy: 0.7370 - val_loss: 1.9198 - val_accuracy: 0.1778
# Epoch 70/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8265 - accuracy: 0.7259
# Epoch 70: accuracy did not improve from 0.74074
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8265 - accuracy: 0.7259 - val_loss: 1.9786 - val_accuracy: 0.1556
# Epoch 71/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8818 - accuracy: 0.6963
# Epoch 71: accuracy did not improve from 0.74074
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8818 - accuracy: 0.6963 - val_loss: 1.8865 - val_accuracy: 0.1778
# Epoch 72/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8034 - accuracy: 0.7296
# Epoch 72: accuracy did not improve from 0.74074
# 34/34 [==============================] - 3s 91ms/step - loss: 0.8034 - accuracy: 0.7296 - val_loss: 2.0154 - val_accuracy: 0.1778
# Epoch 73/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8688 - accuracy: 0.7074
# Epoch 73: accuracy did not improve from 0.74074
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8688 - accuracy: 0.7074 - val_loss: 1.9629 - val_accuracy: 0.1778
# Epoch 74/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7583 - accuracy: 0.7630
# Epoch 74: accuracy improved from 0.74074 to 0.76296, saving model to best_model_apple.h5
# 34/34 [==============================] - 3s 99ms/step - loss: 0.7583 - accuracy: 0.7630 - val_loss: 1.9245 - val_accuracy: 0.2000
# Epoch 75/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6952 - accuracy: 0.7667
# Epoch 75: accuracy improved from 0.76296 to 0.76667, saving model to best_model_apple.h5
# 34/34 [==============================] - 3s 101ms/step - loss: 0.6952 - accuracy: 0.7667 - val_loss: 2.0351 - val_accuracy: 0.1667
# Epoch 76/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7807 - accuracy: 0.7370
# Epoch 76: accuracy did not improve from 0.76667
# 34/34 [==============================] - 3s 92ms/step - loss: 0.7807 - accuracy: 0.7370 - val_loss: 1.8958 - val_accuracy: 0.2000
# Epoch 77/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7757 - accuracy: 0.7259
# Epoch 77: accuracy did not improve from 0.76667
# 34/34 [==============================] - 3s 92ms/step - loss: 0.7757 - accuracy: 0.7259 - val_loss: 1.9109 - val_accuracy: 0.2111
# Epoch 78/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7337 - accuracy: 0.7704
# Epoch 78: accuracy improved from 0.76667 to 0.77037, saving model to best_model_apple.h5
# 34/34 [==============================] - 3s 97ms/step - loss: 0.7337 - accuracy: 0.7704 - val_loss: 2.1563 - val_accuracy: 0.1778
# Epoch 79/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8088 - accuracy: 0.7444
# Epoch 79: accuracy did not improve from 0.77037
# 34/34 [==============================] - 3s 91ms/step - loss: 0.8088 - accuracy: 0.7444 - val_loss: 1.9734 - val_accuracy: 0.2000
# Epoch 80/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7278 - accuracy: 0.7519
# Epoch 80: accuracy did not improve from 0.77037
# 34/34 [==============================] - 3s 91ms/step - loss: 0.7278 - accuracy: 0.7519 - val_loss: 2.0903 - val_accuracy: 0.2222
# Epoch 81/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8775 - accuracy: 0.7074
# Epoch 81: accuracy did not improve from 0.77037
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8775 - accuracy: 0.7074 - val_loss: 2.0318 - val_accuracy: 0.1667
# Epoch 82/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8829 - accuracy: 0.7000
# Epoch 82: accuracy did not improve from 0.77037
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8829 - accuracy: 0.7000 - val_loss: 1.9636 - val_accuracy: 0.1889
# Epoch 83/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8607 - accuracy: 0.6815
# Epoch 83: accuracy did not improve from 0.77037
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8607 - accuracy: 0.6815 - val_loss: 1.9650 - val_accuracy: 0.1778
# Epoch 84/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7370 - accuracy: 0.7778
# Epoch 84: accuracy improved from 0.77037 to 0.77778, saving model to best_model_apple.h5
# 34/34 [==============================] - 3s 99ms/step - loss: 0.7370 - accuracy: 0.7778 - val_loss: 2.1734 - val_accuracy: 0.1667
# Epoch 85/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.7630
# Epoch 85: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 92ms/step - loss: 0.6894 - accuracy: 0.7630 - val_loss: 2.0851 - val_accuracy: 0.1889
# Epoch 86/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7244 - accuracy: 0.7667
# Epoch 86: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 93ms/step - loss: 0.7244 - accuracy: 0.7667 - val_loss: 2.0664 - val_accuracy: 0.2000
# Epoch 87/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7545 - accuracy: 0.7481
# Epoch 87: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 92ms/step - loss: 0.7545 - accuracy: 0.7481 - val_loss: 2.1704 - val_accuracy: 0.1889
# Epoch 88/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8365 - accuracy: 0.6926
# Epoch 88: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 90ms/step - loss: 0.8365 - accuracy: 0.6926 - val_loss: 2.2519 - val_accuracy: 0.1667
# Epoch 89/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8812 - accuracy: 0.6963
# Epoch 89: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8812 - accuracy: 0.6963 - val_loss: 1.9539 - val_accuracy: 0.2111
# Epoch 90/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7967 - accuracy: 0.7481
# Epoch 90: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 93ms/step - loss: 0.7967 - accuracy: 0.7481 - val_loss: 1.9295 - val_accuracy: 0.1778
# Epoch 91/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8767 - accuracy: 0.7370
# Epoch 91: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 93ms/step - loss: 0.8767 - accuracy: 0.7370 - val_loss: 1.9198 - val_accuracy: 0.1889
# Epoch 92/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8118 - accuracy: 0.7185
# Epoch 92: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 90ms/step - loss: 0.8118 - accuracy: 0.7185 - val_loss: 1.8967 - val_accuracy: 0.2000
# Epoch 93/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7890 - accuracy: 0.7407
# Epoch 93: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 92ms/step - loss: 0.7890 - accuracy: 0.7407 - val_loss: 1.9887 - val_accuracy: 0.1667
# Epoch 94/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7367 - accuracy: 0.7556
# Epoch 94: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 92ms/step - loss: 0.7367 - accuracy: 0.7556 - val_loss: 2.0586 - val_accuracy: 0.1667
# Epoch 95/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8130 - accuracy: 0.7111
# Epoch 95: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 93ms/step - loss: 0.8130 - accuracy: 0.7111 - val_loss: 1.8845 - val_accuracy: 0.2333
# Epoch 96/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7161 - accuracy: 0.7556
# Epoch 96: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 92ms/step - loss: 0.7161 - accuracy: 0.7556 - val_loss: 2.0929 - val_accuracy: 0.1778
# Epoch 97/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7521 - accuracy: 0.7370
# Epoch 97: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 92ms/step - loss: 0.7521 - accuracy: 0.7370 - val_loss: 2.1081 - val_accuracy: 0.1667
# Epoch 98/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8315 - accuracy: 0.6889
# Epoch 98: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 92ms/step - loss: 0.8315 - accuracy: 0.6889 - val_loss: 1.9289 - val_accuracy: 0.1667
# Epoch 99/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7797 - accuracy: 0.7185
# Epoch 99: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 91ms/step - loss: 0.7797 - accuracy: 0.7185 - val_loss: 2.0247 - val_accuracy: 0.2000
# Epoch 100/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7849 - accuracy: 0.7370
# Epoch 100: accuracy did not improve from 0.77778
# 34/34 [==============================] - 3s 92ms/step - loss: 0.7849 - accuracy: 0.7370 - val_loss: 2.1781 - val_accuracy: 0.1778

# %%
# Plot training & validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Get true labels and predictions
test_labels = np.concatenate([y for x, y in test_dataset], axis=0)
predictions = np.argmax(model.predict(test_dataset), axis=-1)
# Out:
# 12/12 [==============================] - 0s 27ms/step

# %%
# Classification report
print("Classification Report:")
print(classification_report(test_labels, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.19      1.00      0.31        15
#            2       0.00      0.00      0.00        15
#            3       0.00      0.00      0.00        15
#            4       0.22      0.13      0.17        15
#
#     accuracy                           0.19        90
#    macro avg       0.08      0.23      0.10        90
# weighted avg       0.07      0.19      0.08        90
# c:\Users\rafin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\rafin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\rafin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Confusion matrix
conf_matrix = confusion_matrix(test_labels, predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(5)], yticklabels=[str(i) for i in range(5)])

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
