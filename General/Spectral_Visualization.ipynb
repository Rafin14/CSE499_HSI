# %%
from spectral import *

img = open_image('MA1_H1.bil.hdr')

view = imshow(img, (29, 19, 9))
# Out:
# c:\Users\rafin\AppData\Local\Programs\Python\Python310\lib\site-packages\spectral\graphics\spypylab.py:796: UserWarning: Failed to create RectangleSelector object. Interactive pixel class labeling will be unavailable.
#   warnings.warn(msg)

# %%
gt = open_image('MA1_H1.bil.hdr').read_band(250)

view = imshow(classes=gt)

# %%
view = imshow(img, (30, 20, 10), classes=gt)

# %%
view = imshow(img, (30, 20, 10), classes=gt)

view.set_display_mode('overlay')

view.class_alpha = 0.5
