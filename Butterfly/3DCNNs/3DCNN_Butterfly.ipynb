# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tensorflow.keras import models, layers, regularizers

# %%
config = tf.compat.v1.ConfigProto(gpu_options =
                         tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8)
)

config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)

physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
# Out:
# WARNING:tensorflow:From C:\Users\rafin\AppData\Local\Temp\ipykernel_15308\717319033.py:7: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Num GPUs Available:  1

# %%
data = np.load('Butterfly_filtered.npy', allow_pickle= True)
#data_test = np.load('Datasets/Apple_labels.npy', allow_pickle= True)

labels = np.load('Butterfly_labels_filtered.npy', allow_pickle= True)
#test_labels = np.load('Datasets/test_labels.npy', allow_pickle= True)

data.shape, labels.shape
# Out:
# ((164, 192, 32, 32), (164,))

# %%
data = np.transpose(data, (0, 2, 3, 1))  # (height, width, depth, channels)

data.shape
# Out:
# (164, 32, 32, 192)

# %%
mean = data.mean(axis=(0, 1, 2), keepdims=True)
std_dev = data.std(axis=(0, 1, 2), keepdims=True)

# Z-score normalization
data = (data - mean) / std_dev

print("Dataset shape:", data.shape)
# Out:
# Dataset shape: (164, 32, 32, 192)

# %%
# Split data into training, validation, and testing sets
data_train, data_test, train_labels, test_labels = train_test_split(data, labels, test_size = 0.25, random_state = 42, stratify = labels)

data_train.shape, train_labels.shape, data_test.shape, test_labels.shape
# Out:
# ((123, 32, 32, 192), (123,), (41, 32, 32, 192), (41,))

# %%
# Simulated HSI data
hsi_image_train = data_train
hsi_image_test = data_test

# Reshape to (264 * 1024, 320)
hsi_reshaped_train = hsi_image_train.reshape(-1, 192)
hsi_reshaped_test = hsi_image_test.reshape(-1, 192)

hsi_reshaped_train.shape, hsi_reshaped_test.shape
# Out:
# ((125952, 192), (41984, 192))

# %%
# Apply PCA
pca = PCA()
hsi_train_pca = pca.fit_transform(hsi_reshaped_train)

explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance)

# %%
plt.figure(figsize=(5, 5))
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--')
plt.xlabel('Number of Dimensions')
plt.ylabel('Total Variance Retained')
plt.title('Variance Retained vs No. of Dimensions')
plt.grid()
plt.show()

# %%
#No. of Dimensions that retains 95% varinace:
optimal_components = np.argmax(cumulative_explained_variance >= 0.999) + 1 
print(f"Number of Dimensions to retain 99% variance: {optimal_components}")

pca = PCA(n_components=optimal_components)

X_train_PCA = pca.fit_transform(hsi_reshaped_train)
X_test_pca = pca.transform(hsi_reshaped_test)

X_train_PCA.shape, X_test_pca.shape
# Out:
# Number of Dimensions to retain 99% variance: 140
# ((125952, 140), (41984, 140))

# %%
# Reshape back to the spatial dimensions
data_train = X_train_PCA.reshape(123, 32, 32, optimal_components)
data_test = X_test_pca.reshape(41, 32, 32, optimal_components)

data_train.shape, data_test.shape
# Out:
# ((123, 32, 32, 140), (41, 32, 32, 140))

# %%
le= LabelEncoder()
y_train = le.fit_transform(train_labels)

le2= LabelEncoder()
y_test= le2.fit_transform(test_labels)

# %%
# Add channel dimension to data
data_train = data_train[..., np.newaxis]
data_test = data_test[..., np.newaxis]

data_train.shape, data_test.shape
# Out:
# ((123, 32, 32, 140, 1), (41, 32, 32, 140, 1))

# %%
def augment_data(sample, label):
    
    # Ensure both are the same type
    random_scale = tf.cast(tf.random.uniform([], 0.9, 1.1), dtype=sample.dtype)
    sample = sample * random_scale  # Random scale between 0.9 and 1.1
    
    return sample, label

# %%
# Convert data to TensorFlow dataset

train_dataset = tf.data.Dataset.from_tensor_slices((data_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((data_test, y_test))

# Apply augmentation only on training data
train_dataset = train_dataset.map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle, batch, and prefetch
batch_size = 8

train_dataset = train_dataset.shuffle(buffer_size=100).batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
'''
tf.random.set_seed(1234)

# Define the model architecture as in the previous answer
input_shape = (32, 32, 199, 1)

model = models.Sequential([
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu', input_shape=input_shape),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu'),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    
    layers.Flatten(),
    
    layers.Dense(128, activation='relu'),
    layers.Dense(2, activation='sigmoid')
])

model.summary()
'''

tf.random.set_seed(1234)

input_shape = (32, 32, optimal_components, 1)

model = models.Sequential([
    
    
    #1st Conv Layer
    layers.Conv3D(32, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.01), input_shape=input_shape),
    #layers.BatchNormalization(),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3
     
     
     
    #2nd Conv Layer
    layers.Conv3D(64, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.001)),
    #layers.BatchNormalization(),
    
    
    
    #3rd Conv Layer
    layers.Conv3D(128, kernel_size=(3, 3, 3), strides=(1, 1, 1), activation='relu',
                  kernel_regularizer=regularizers.l2(0.0001)),
    #layers.BatchNormalization(),
    layers.AveragePooling3D(pool_size=(2, 2, 2)),
    #layers.Dropout(0.3),  # Dropout with a rate of 0.3


    layers.Flatten(),
    
    
    #1st FC layer
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),  # Dropout with a rate of 0.5
    #layers.BatchNormalization(),
    
    
    
    #2nd FC layer
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
    layers.Dense(4, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 30, 138, 32)   896
#
#  average_pooling3d (AverageP  (None, 15, 15, 69, 32)   0
#  ooling3D)
#
#  conv3d_1 (Conv3D)           (None, 13, 13, 67, 64)    55360
#
#  conv3d_2 (Conv3D)           (None, 11, 11, 65, 128)   221312
#
#  average_pooling3d_1 (Averag  (None, 5, 5, 32, 128)    0
#  ePooling3D)
#
#  flatten (Flatten)           (None, 102400)            0
#
#  dense (Dense)               (None, 128)               13107328
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 13,393,412
# Trainable params: 13,393,412
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

'''
history = model.fit(train_dataset, epochs=100, validation_data=test_dataset, callbacks=[
                        tf.keras.callbacks.EarlyStopping(
                            monitor = 'loss',
                            patience = 5,
                            restore_best_weights = True
                        )
                    ])

'''
# Define the callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = 'best_model_butterfly_filtered.h5',            # Path to save the best model
    monitor = 'accuracy',                   # Metric to monitor
    save_best_only = True,                 # Save only the best model
    save_weights_only = False,             # Save the entire model (architecture + weights)
    mode = 'max',                          # Mode 'max' because we want to maximize accuracy
    verbose = 1
)

early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'loss',
    patience = 15,
    restore_best_weights = True
)

# Train the model with the callbacks
history = model.fit(
    train_dataset,
    epochs = 100,
    validation_data = test_dataset,
    callbacks = [checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: 1.6534 - accuracy: 0.2764
# Epoch 1: accuracy improved from -inf to 0.27642, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 12s 187ms/step - loss: 1.6534 - accuracy: 0.2764 - val_loss: 1.6008 - val_accuracy: 0.3659
# Epoch 2/100
# 15/16 [===========================>..] - ETA: 0s - loss: 1.5902 - accuracy: 0.2083
# Epoch 2: accuracy did not improve from 0.27642
# 16/16 [==============================] - 1s 87ms/step - loss: 1.5857 - accuracy: 0.2195 - val_loss: 1.4753 - val_accuracy: 0.3171
# Epoch 3/100
# 15/16 [===========================>..] - ETA: 0s - loss: 1.3816 - accuracy: 0.5000
# Epoch 3: accuracy improved from 0.27642 to 0.49593, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 100ms/step - loss: 1.3776 - accuracy: 0.4959 - val_loss: 1.0231 - val_accuracy: 0.7073
# Epoch 4/100
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2275 - accuracy: 0.5750
# Epoch 4: accuracy improved from 0.49593 to 0.56911, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 101ms/step - loss: 1.2233 - accuracy: 0.5691 - val_loss: 1.0278 - val_accuracy: 0.7317
# Epoch 5/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9251 - accuracy: 0.7083
# Epoch 5: accuracy improved from 0.56911 to 0.71545, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 100ms/step - loss: 0.9105 - accuracy: 0.7154 - val_loss: 0.7079 - val_accuracy: 0.7561
# Epoch 6/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7061 - accuracy: 0.7917
# Epoch 6: accuracy improved from 0.71545 to 0.79675, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 100ms/step - loss: 0.7040 - accuracy: 0.7967 - val_loss: 0.7329 - val_accuracy: 0.7317
# Epoch 7/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.8808 - accuracy: 0.8167
# Epoch 7: accuracy improved from 0.79675 to 0.81301, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 99ms/step - loss: 0.8758 - accuracy: 0.8130 - val_loss: 1.2869 - val_accuracy: 0.6585
# Epoch 8/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7132 - accuracy: 0.7833
# Epoch 8: accuracy did not improve from 0.81301
# 16/16 [==============================] - 1s 86ms/step - loss: 0.7205 - accuracy: 0.7805 - val_loss: 0.9691 - val_accuracy: 0.7073
# Epoch 9/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7585 - accuracy: 0.8333
# Epoch 9: accuracy improved from 0.81301 to 0.83740, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 99ms/step - loss: 0.7464 - accuracy: 0.8374 - val_loss: 0.6861 - val_accuracy: 0.8049
# Epoch 10/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5192 - accuracy: 0.8833
# Epoch 10: accuracy improved from 0.83740 to 0.88618, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 100ms/step - loss: 0.5124 - accuracy: 0.8862 - val_loss: 0.7635 - val_accuracy: 0.7805
# Epoch 11/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5284 - accuracy: 0.8917
# Epoch 11: accuracy improved from 0.88618 to 0.89431, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 99ms/step - loss: 0.5245 - accuracy: 0.8943 - val_loss: 0.6658 - val_accuracy: 0.7805
# Epoch 12/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4468 - accuracy: 0.9417
# Epoch 12: accuracy improved from 0.89431 to 0.94309, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 99ms/step - loss: 0.4423 - accuracy: 0.9431 - val_loss: 0.6570 - val_accuracy: 0.7805
# Epoch 13/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4935 - accuracy: 0.8833
# Epoch 13: accuracy did not improve from 0.94309
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4908 - accuracy: 0.8862 - val_loss: 0.6833 - val_accuracy: 0.7805
# Epoch 14/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3932 - accuracy: 0.9333
# Epoch 14: accuracy did not improve from 0.94309
# 16/16 [==============================] - 1s 88ms/step - loss: 0.4185 - accuracy: 0.9187 - val_loss: 0.9975 - val_accuracy: 0.8049
# Epoch 15/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4265 - accuracy: 0.9250
# Epoch 15: accuracy did not improve from 0.94309
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4218 - accuracy: 0.9268 - val_loss: 0.6911 - val_accuracy: 0.7805
# Epoch 16/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4524 - accuracy: 0.9417
# Epoch 16: accuracy did not improve from 0.94309
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4529 - accuracy: 0.9431 - val_loss: 0.6655 - val_accuracy: 0.7561
# Epoch 17/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3403 - accuracy: 0.9333
# Epoch 17: accuracy did not improve from 0.94309
# 16/16 [==============================] - 1s 88ms/step - loss: 0.3643 - accuracy: 0.9268 - val_loss: 0.7786 - val_accuracy: 0.7805
# Epoch 18/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3320 - accuracy: 0.9583
# Epoch 18: accuracy improved from 0.94309 to 0.95122, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 101ms/step - loss: 0.3528 - accuracy: 0.9512 - val_loss: 0.6907 - val_accuracy: 0.7805
# Epoch 19/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3574 - accuracy: 0.9333
# Epoch 19: accuracy did not improve from 0.95122
# 16/16 [==============================] - 1s 87ms/step - loss: 0.3547 - accuracy: 0.9350 - val_loss: 0.9451 - val_accuracy: 0.7317
# Epoch 20/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4101 - accuracy: 0.9083
# Epoch 20: accuracy did not improve from 0.95122
# 16/16 [==============================] - 1s 85ms/step - loss: 0.4054 - accuracy: 0.9106 - val_loss: 0.5560 - val_accuracy: 0.8049
# Epoch 21/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4058 - accuracy: 0.9417
# Epoch 21: accuracy did not improve from 0.95122
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4014 - accuracy: 0.9431 - val_loss: 0.5654 - val_accuracy: 0.8049
# Epoch 22/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4840 - accuracy: 0.9083
# Epoch 22: accuracy did not improve from 0.95122
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4800 - accuracy: 0.9106 - val_loss: 0.7527 - val_accuracy: 0.7805
# Epoch 23/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3803 - accuracy: 0.9333
# Epoch 23: accuracy did not improve from 0.95122
# 16/16 [==============================] - 1s 86ms/step - loss: 0.3767 - accuracy: 0.9350 - val_loss: 0.6130 - val_accuracy: 0.7805
# Epoch 24/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3469 - accuracy: 0.9333
# Epoch 24: accuracy did not improve from 0.95122
# 16/16 [==============================] - 1s 87ms/step - loss: 0.3437 - accuracy: 0.9350 - val_loss: 0.5917 - val_accuracy: 0.8049
# Epoch 25/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3185 - accuracy: 0.9583
# Epoch 25: accuracy improved from 0.95122 to 0.95935, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 100ms/step - loss: 0.3162 - accuracy: 0.9593 - val_loss: 0.7186 - val_accuracy: 0.7317
# Epoch 26/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2898 - accuracy: 0.9750
# Epoch 26: accuracy improved from 0.95935 to 0.97561, saving model to best_model_butterfly_filtered.h5
# 16/16 [==============================] - 2s 99ms/step - loss: 0.2874 - accuracy: 0.9756 - val_loss: 0.9187 - val_accuracy: 0.7317
# Epoch 27/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2803 - accuracy: 0.9500
# Epoch 27: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.2780 - accuracy: 0.9512 - val_loss: 0.5591 - val_accuracy: 0.8537
# Epoch 28/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2715 - accuracy: 0.9750
# Epoch 28: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 87ms/step - loss: 0.2692 - accuracy: 0.9756 - val_loss: 0.7080 - val_accuracy: 0.8293
# Epoch 29/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2968 - accuracy: 0.9417
# Epoch 29: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.2951 - accuracy: 0.9431 - val_loss: 1.0320 - val_accuracy: 0.7561
# Epoch 30/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3250 - accuracy: 0.9500
# Epoch 30: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 85ms/step - loss: 0.3223 - accuracy: 0.9512 - val_loss: 1.6734 - val_accuracy: 0.6829
# Epoch 31/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5642 - accuracy: 0.9083
# Epoch 31: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.5621 - accuracy: 0.9106 - val_loss: 0.7545 - val_accuracy: 0.7561
# Epoch 32/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4047 - accuracy: 0.9500
# Epoch 32: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 88ms/step - loss: 0.4018 - accuracy: 0.9512 - val_loss: 0.8792 - val_accuracy: 0.7561
# Epoch 33/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4452 - accuracy: 0.9500
# Epoch 33: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4410 - accuracy: 0.9512 - val_loss: 1.0174 - val_accuracy: 0.7561
# Epoch 34/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4908 - accuracy: 0.9333
# Epoch 34: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4853 - accuracy: 0.9350 - val_loss: 0.8222 - val_accuracy: 0.7561
# Epoch 35/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4630 - accuracy: 0.9333
# Epoch 35: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4601 - accuracy: 0.9350 - val_loss: 0.7701 - val_accuracy: 0.7317
# Epoch 36/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4093 - accuracy: 0.9500
# Epoch 36: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4059 - accuracy: 0.9512 - val_loss: 0.9395 - val_accuracy: 0.7073
# Epoch 37/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4941 - accuracy: 0.9750
# Epoch 37: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4884 - accuracy: 0.9756 - val_loss: 0.7092 - val_accuracy: 0.8049
# Epoch 38/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4395 - accuracy: 0.9583
# Epoch 38: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4350 - accuracy: 0.9593 - val_loss: 0.6300 - val_accuracy: 0.7805
# Epoch 39/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5130 - accuracy: 0.9750
# Epoch 39: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.5199 - accuracy: 0.9756 - val_loss: 0.8351 - val_accuracy: 0.7073
# Epoch 40/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5662 - accuracy: 0.9333
# Epoch 40: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.5584 - accuracy: 0.9350 - val_loss: 0.8769 - val_accuracy: 0.7805
# Epoch 41/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4052 - accuracy: 0.9750
# Epoch 41: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 86ms/step - loss: 0.4014 - accuracy: 0.9756 - val_loss: 0.8122 - val_accuracy: 0.7317
# Epoch 42/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4346 - accuracy: 0.9417
# Epoch 42: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 85ms/step - loss: 0.4310 - accuracy: 0.9431 - val_loss: 0.7962 - val_accuracy: 0.7805
# Epoch 43/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4072 - accuracy: 0.9333
# Epoch 43: accuracy did not improve from 0.97561
# 16/16 [==============================] - 1s 87ms/step - loss: 0.4040 - accuracy: 0.9350 - val_loss: 1.3993 - val_accuracy: 0.7073

# %%
# Plot training & validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# Get true labels and predictions
test_labels = np.concatenate([y for x, y in test_dataset], axis=0)
predictions = np.argmax(model.predict(test_dataset), axis=-1)
# Out:
# 6/6 [==============================] - 0s 25ms/step

# %%
# Classification report
print("Classification Report:")
print(classification_report(test_labels, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.45      0.62        11
#            1       0.69      1.00      0.82         9
#            2       0.82      0.90      0.86        10
#            3       0.92      1.00      0.96        11
#
#     accuracy                           0.83        41
#    macro avg       0.86      0.84      0.81        41
# weighted avg       0.87      0.83      0.81        41

# %%
# Confusion matrix
conf_matrix = confusion_matrix(test_labels, predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(4)], yticklabels=[str(i) for i in range(4)])

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()
